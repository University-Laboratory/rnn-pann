# %% [markdown]
# # note4: Simulation waveforms -> BuckConverterCell + GRU で挙動再現（rollout 学習版）
#
# - 目的: シミュレーションで生成した波形（擬似「計測」）から、
#
#   - **BuckConverterCell** を回路パラメータ推定（rollout 損失）で学習
#   - **GRU** を残差（擬似ノイズ）予測で学習
#   - **Buck + GRU** の合成で波形を再現
#
# - 方針: `plan.md` に従い、Buck は **teacher forcing ではなく window rollout 損失**で学習する

# %%
from __future__ import annotations

from dataclasses import asdict, dataclass
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn, optim

from src.utils.models import BuckConverterCell, GRUModel
from src.utils.plot_data import (
    plot_buck_gru_components_tail,
    plot_compare_tail,
    plot_iLvC,
    plot_param_learning_progress,
    plot_u_vs_iL_vC,
)
from src.utils.save_log import (
    create_result_dir,
    format_kv_lines,
    init_log,
    save_figure_to_log,
    save_text_output,
)

# 再現性
seed: int = 10
np.random.seed(seed)
torch.manual_seed(seed)

# 実行環境
# if torch.backends.mps.is_available():
#     device: torch.device = torch.device("mps")
# elif torch.cuda.is_available():
#     device: torch.device = torch.device("cuda")
# else:
#     device: torch.device = torch.device("cpu")
device: torch.device = torch.device("cpu")
print(f"device={device}")
# Out:
# device=cpu

# %%
# keep_log: bool = True
keep_log: bool = False


@dataclass(frozen=True)
class Params:
    # --- 真値（シミュレーション生成用）---
    L_true: float = 220e-6
    C_true: float = 75e-6
    R_true: float = 5.0

    Vin: float = 10.0
    Vref: float = 5.0
    duty: float = Vref / Vin

    f_sw: float = 1e5
    T: float = 1.0 / f_sw

    # シミュレーションは長めに回して定常に入れたあと、学習には末尾だけを使う
    cycles: int = 1200
    samples_per_cycle: int = 200
    train_cycles: int = 10  # 末尾から何周期ぶんを学習に使うか

    # --- 擬似「計測」ノイズ ---
    noise_std_iL: float = 0.02  # [A]
    noise_std_vC: float = 0.02  # [V]

    # --- データ分割（時間方向に連続で分割）---
    train_ratio: float = 0.5
    valid_ratio: float = 0.25

    # --- Buck 学習（rollout）---
    L_init: float = 200e-6
    C_init: float = 100e-6
    R_init: float = 8.0

    # rollout は不安定になりやすいので 1 桁下げる
    lr_l: float = 5e-3
    lr_c: float = 1e-3
    lr_r: float = 2e-3

    epochs_buck: int = 8000
    win_len: int = 50
    batch_size: int = 256
    grad_clip_norm: float = 5.0

    # --- GRU（残差学習）---
    seq_length: int = 10
    gru_lr: float = 1e-3
    epochs_gru: int = 300


params = Params()

if keep_log:
    result_dir: Path = create_result_dir("note4", config_dict=asdict(params))
    init_log(result_dir, "actual_machine_notebooks/note4/note_sim.ipynb")
    save_text_output(result_dir, text=format_kv_lines(asdict(params)), title="Params")
    print(f"log_dir={result_dir}")
# Out:
# log_dir=/Users/otsukanaoya/Desktop/unilab/rnn-pann/results/20251222_142210_323_note4

# %%
# --- 入力系列の生成（vs, u, dt）---
num_steps: int = int(params.cycles * params.samples_per_cycle)  # N

# t は N+1 点、dt は N 点
# 注意: t[0]=0 を含める

t_raw: np.ndarray = np.linspace(
    0.0, params.cycles * params.T, num_steps + 1, dtype=np.float64
)
dt_raw: np.ndarray = np.diff(t_raw)

# スイッチング信号 u(t)
duty_phase: np.ndarray = (t_raw[:-1] % params.T) / params.T
u_raw: np.ndarray = (duty_phase < params.duty).astype(np.float64)

# 入力電圧 vs(t)
vs_raw: np.ndarray = np.full(
    shape=(num_steps,), fill_value=params.Vin, dtype=np.float64
)

x_series_np: np.ndarray = np.stack([vs_raw, u_raw, dt_raw], axis=1)  # [N,3]

# torch 化
x_series: torch.Tensor = torch.tensor(x_series_np, dtype=torch.float32, device=device)

print(f"t_raw.shape={t_raw.shape}")
print(f"x_series.shape={tuple(x_series.shape)}")
# Out:
# t_raw.shape=(240001,)
# x_series.shape=(240000, 3)

# %%
# --- 真値 Buck で波形生成（状態: h=[iL, vC]）---
true_cell = BuckConverterCell(
    L_init=params.L_true, C_init=params.C_true, R_init=params.R_true
).to(device)
true_cell.eval()

# 事前確保して高速化（list+cat は遅くなりやすい）
with torch.no_grad():
    h_true_series = torch.empty((num_steps + 1, 2), dtype=torch.float32, device=device)

    h_cur: torch.Tensor = torch.zeros(1, 2, dtype=torch.float32, device=device)
    h_true_series[0] = h_cur[0]

    for k in range(num_steps):
        h_cur = true_cell(h_cur, x_series[k : k + 1])
        h_true_series[k + 1] = h_cur[0]

# 擬似「計測」 = 真値 + 白色ノイズ
# noise_series = torch.empty_like(h_true_series)
# noise_series[:, 0] = torch.randn(num_steps + 1, device=device) * float(
#     params.noise_std_iL
# )
# noise_series[:, 1] = torch.randn(num_steps + 1, device=device) * float(
#     params.noise_std_vC
# )

# h_meas_series: torch.Tensor = h_true_series + noise_series
h_meas_series: torch.Tensor = h_true_series

# 可視化（全体）
iL_meas = h_meas_series[:, 0].detach().cpu().numpy()
vC_meas = h_meas_series[:, 1].detach().cpu().numpy()

fig, _ = plot_u_vs_iL_vC(
    t_raw,
    u_raw,
    vs_raw,
    iL_meas,
    vC_meas,
    title="Simulated (pseudo-measured)",
)
_ = plot_iLvC(
    t_raw,
    iL_meas,
    vC_meas,
    T=float(params.T),
    title="Simulated (pseudo-measured)",
)

if keep_log:
    save_figure_to_log(fig, "sim_pseudo_measured", result_dir, "擬似計測波形")

# %%
# --- 学習には「末尾 train_cycles 周期」だけを使う（BuckもGRUも同一）---
tail_steps: int = int(params.train_cycles * params.samples_per_cycle)  # N_tail
if tail_steps <= 0:
    raise ValueError("train_cycles must be positive")
if tail_steps >= int(x_series.shape[0]):
    raise ValueError("train_cycles が大きすぎます（シミュレーション長より長い）")

# 時刻は切り出し後に 0 始まりに揃える
# t_raw: [N_total+1] -> [N_tail+1]
t_raw = t_raw[-(tail_steps + 1) :]
t_raw = t_raw - t_raw[0]

# 入力系列（長さN_total -> N_tail）
u_raw = u_raw[-tail_steps:]
vs_raw = vs_raw[-tail_steps:]
x_series = x_series[-tail_steps:]

# 状態系列（長さN_total+1 -> N_tail+1）
h_true_series = h_true_series[-(tail_steps + 1) :]
h_meas_series = h_meas_series[-(tail_steps + 1) :]

# 後段の整合のため更新
num_steps = int(tail_steps)

# 可視化（学習に使う末尾10周期）
iL_tail = h_meas_series[:, 0].detach().cpu().numpy()
vC_tail = h_meas_series[:, 1].detach().cpu().numpy()

fig_tail, _ = plot_u_vs_iL_vC(
    t_raw,
    u_raw,
    vs_raw,
    iL_tail,
    vC_tail,
    title=f"Training data (tail {int(params.train_cycles)} cycles)",
)
plt.show()

if keep_log:
    save_figure_to_log(
        fig_tail, "training_data_tail", result_dir, "学習データ（末尾10周期）"
    )

# --- 連続区間で train/valid/test に分割（状態は N+1, 入力は N）---
N: int = int(num_steps)
train_steps: int = int(N * params.train_ratio)
valid_steps: int = int(N * params.valid_ratio)
test_steps: int = N - train_steps - valid_steps

if test_steps <= int(params.win_len) + int(params.seq_length) + 1:
    raise ValueError(
        "データが短すぎます。train_cycles/samples_per_cycle/ratio を見直してください。"
    )

# 系列（長さの整合）
h_meas_series = h_meas_series.to(device)
h_true_series = h_true_series.to(device)

# step系列（長さ N）
h_meas_steps: torch.Tensor = h_meas_series[:-1]
h_true_steps: torch.Tensor = h_true_series[:-1]

# 1つ先の状態（長さ N）
h_meas_next: torch.Tensor = h_meas_series[1:]
h_true_next: torch.Tensor = h_true_series[1:]

# 分割
h_meas_train_steps = h_meas_steps[:train_steps]
h_meas_valid_steps = h_meas_steps[train_steps : train_steps + valid_steps]
h_meas_test_steps = h_meas_steps[train_steps + valid_steps :]

h_meas_train_next = h_meas_next[:train_steps]
h_meas_valid_next = h_meas_next[train_steps : train_steps + valid_steps]
h_meas_test_next = h_meas_next[train_steps + valid_steps :]

x_train = x_series[:train_steps]
x_valid = x_series[train_steps : train_steps + valid_steps]
x_test = x_series[train_steps + valid_steps :]

print(
    f"N={N} (tail), train_steps={train_steps}, "
    f"valid_steps={valid_steps}, test_steps={test_steps}"
)
print(
    f"h_meas_train_steps={tuple(h_meas_train_steps.shape)}, "
    f"x_train={tuple(x_train.shape)}"
)
# Out:
# N=2000 (tail), train_steps=1000, valid_steps=500, test_steps=500
# h_meas_train_steps=(1000, 2), x_train=(1000, 3)

# %%
def rollout_cell(
    cell: BuckConverterCell,
    h0: torch.Tensor,  # [B,2]
    x_seq: torch.Tensor,  # [B,T,3]
) -> torch.Tensor:
    """BuckConverterCell を逐次適用して roll-out する（学習用）"""
    if h0.ndim != 2 or h0.shape[1] != 2:
        raise ValueError("h0 must be [B,2]")
    if x_seq.ndim != 3 or x_seq.shape[2] != 3:
        raise ValueError("x_seq must be [B,T,3]")

    # B: int = int(h0.shape[0])
    T: int = int(x_seq.shape[1])

    h: torch.Tensor = h0
    preds: list[torch.Tensor] = []

    for t in range(T):
        h = cell(h, x_seq[:, t, :])
        preds.append(h)

    # [B,T,2]（各ステップの「次状態」）
    return torch.stack(preds, dim=1)


def make_windows(
    h_steps: torch.Tensor,  # [N,2]
    x_steps: torch.Tensor,  # [N,3]
    win_len: int,
    batch_size: int,
) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """連続系列から window をサンプリング

    - h0: [B,2]（開始状態）
    - x:  [B,win_len,3]（入力列）
    - y:  [B,win_len,2]（真の次状態列）
    """
    if win_len <= 0:
        raise ValueError("win_len must be positive")

    N_local: int = int(h_steps.shape[0])
    max_start: int = N_local - win_len - 1
    if max_start <= 0:
        raise ValueError("series is too short for the given win_len")

    # [0, max_start] から開始点を選ぶ（i=開始状態、教師は i+1..i+win_len）
    start_idx = torch.randint(
        low=0, high=max_start, size=(batch_size,), device=h_steps.device
    )

    h0 = h_steps[start_idx]  # [B,2]

    # x: i..i+win_len-1
    x = torch.stack([x_steps[i : i + win_len] for i in start_idx.tolist()], dim=0)

    # y: (i+1)..(i+win_len)
    y = torch.stack(
        [h_steps[i + 1 : i + 1 + win_len] for i in start_idx.tolist()], dim=0
    )

    return h0, x, y


def rollout_mse_loss(
    cell: BuckConverterCell,
    h0: torch.Tensor,
    x_win: torch.Tensor,
    y_win: torch.Tensor,
) -> torch.Tensor:
    """window rollout の MSE 損失"""
    pred = rollout_cell(cell, h0=h0, x_seq=x_win)  # [B,win_len,2]
    return nn.functional.mse_loss(pred, y_win)


@torch.no_grad()
def rollout_full_series(
    cell: BuckConverterCell,
    h0_1x2: torch.Tensor,  # [1,2]
    x_steps: torch.Tensor,  # [N,3]
) -> torch.Tensor:
    """系列全体を roll-out（推論・評価用）

    Returns:
        h_series_pred: [N+1,2]
    """
    if h0_1x2.shape != (1, 2):
        raise ValueError("h0_1x2 must be shape (1,2)")

    h_list: list[torch.Tensor] = [h0_1x2]
    h_cur: torch.Tensor = h0_1x2

    for k in range(int(x_steps.shape[0])):
        h_cur = cell(h_cur, x_steps[k : k + 1])
        h_list.append(h_cur)

    return torch.cat(h_list, dim=0)

# %%
# --- BuckConverterCell を rollout 損失で学習 ---
cell = BuckConverterCell(
    L_init=params.L_init, C_init=params.C_init, R_init=params.R_init
).to(device)

optimizer = optim.Adam(
    [
        {"params": [cell.log_L], "lr": params.lr_l},
        {"params": [cell.log_C], "lr": params.lr_c},
        {"params": [cell.log_R], "lr": params.lr_r},
    ]
)

loss_history: dict[str, list[float]] = {
    "train_roll": [],
    "valid_roll": [],
    "train_tf": [],
    "valid_tf": [],
}
param_history: dict[str, list[float]] = {"L": [], "C": [], "R": []}


def teacher_forcing_loss(
    h_steps: torch.Tensor, x_steps: torch.Tensor, h_next: torch.Tensor
) -> torch.Tensor:
    pred_next = cell(h_steps, x_steps)
    return nn.functional.mse_loss(pred_next, h_next)


@torch.no_grad()
def estimate_rollout_loss(
    h_steps: torch.Tensor,
    x_steps: torch.Tensor,
    win_len: int,
    n_batches: int,
    batch_size: int,
) -> float:
    cell.eval()
    losses: list[float] = []
    for _ in range(n_batches):
        h0_b, x_b, y_b = make_windows(
            h_steps, x_steps, win_len=win_len, batch_size=batch_size
        )
        loss = rollout_mse_loss(cell, h0=h0_b, x_win=x_b, y_win=y_b)
        losses.append(float(loss.detach().cpu().item()))
    return float(np.mean(losses))


log_every: int = 200
valid_batches: int = 10

for epoch in range(1, int(params.epochs_buck) + 1):
    cell.train()
    optimizer.zero_grad(set_to_none=True)

    h0_b, x_b, y_b = make_windows(
        h_meas_train_steps,
        x_train,
        win_len=int(params.win_len),
        batch_size=int(params.batch_size),
    )

    loss_roll = rollout_mse_loss(cell, h0=h0_b, x_win=x_b, y_win=y_b)
    loss_roll.backward()

    # 勾配クリップ（rollout 学習の発散対策）
    nn.utils.clip_grad_norm_(cell.parameters(), max_norm=float(params.grad_clip_norm))
    optimizer.step()

    if epoch % log_every == 0 or epoch == 1:
        cell.eval()
        with torch.no_grad():
            train_tf = float(
                teacher_forcing_loss(h_meas_train_steps, x_train, h_meas_train_next)
                .cpu()
                .item()
            )
            valid_tf = float(
                teacher_forcing_loss(h_meas_valid_steps, x_valid, h_meas_valid_next)
                .cpu()
                .item()
            )
            train_roll = estimate_rollout_loss(
                h_meas_train_steps,
                x_train,
                win_len=int(params.win_len),
                n_batches=valid_batches,
                batch_size=int(params.batch_size),
            )
            valid_roll = estimate_rollout_loss(
                h_meas_valid_steps,
                x_valid,
                win_len=int(params.win_len),
                n_batches=valid_batches,
                batch_size=int(params.batch_size),
            )

        loss_history["train_tf"].append(train_tf)
        loss_history["valid_tf"].append(valid_tf)
        loss_history["train_roll"].append(train_roll)
        loss_history["valid_roll"].append(valid_roll)

        L_est = float(cell.log_L.exp().detach().cpu().item())
        C_est = float(cell.log_C.exp().detach().cpu().item())
        R_est = float(cell.log_R.exp().detach().cpu().item())
        param_history["L"].append(L_est)
        param_history["C"].append(C_est)
        param_history["R"].append(R_est)

        print(
            f"epoch={epoch:5d} "
            f"roll(train/valid)={train_roll:.3e}/{valid_roll:.3e} "
            f"tf(train/valid)={train_tf:.3e}/{valid_tf:.3e} "
            f"L={L_est * 1e6:.1f}uH C={C_est * 1e6:.1f}uF R={R_est:.2f}ohm"
        )

# 学習後の推定値
L_hat: float = float(cell.log_L.exp().detach().cpu().item())
C_hat: float = float(cell.log_C.exp().detach().cpu().item())
R_hat: float = float(cell.log_R.exp().detach().cpu().item())
print(f"L_hat={L_hat:.6e}, C_hat={C_hat:.6e}, R_hat={R_hat:.6e}")

if keep_log:
    save_text_output(
        result_dir,
        text=f"L_hat={L_hat:.6e}\nC_hat={C_hat:.6e}\nR_hat={R_hat:.6e}\n",
        title="Buck 推定値",
    )
# Out:
# epoch=    1 roll(train/valid)=1.863e-05/1.878e-05 tf(train/valid)=2.321e-08/2.322e-08 L=201.0uH C=100.1uF R=7.98ohm
# epoch=  200 roll(train/valid)=1.431e-06/1.465e-06 tf(train/valid)=1.699e-09/1.703e-09 L=220.0uH C=113.2uF R=5.75ohm
# epoch=  400 roll(train/valid)=3.516e-08/3.738e-08 tf(train/valid)=4.807e-11/4.852e-11 L=220.0uH C=114.6uF R=5.07ohm
# epoch=  600 roll(train/valid)=2.040e-08/2.015e-08 tf(train/valid)=2.863e-11/2.867e-11 L=220.0uH C=114.5uF R=5.01ohm
# epoch=  800 roll(train/valid)=2.006e-08/1.981e-08 tf(train/valid)=2.822e-11/2.826e-11 L=220.0uH C=114.2uF R=5.01ohm
# epoch= 1000 roll(train/valid)=1.991e-08/2.043e-08 tf(train/valid)=2.805e-11/2.808e-11 L=220.0uH C=113.9uF R=5.00ohm
# epoch= 1200 roll(train/valid)=1.983e-08/1.968e-08 tf(train/valid)=2.781e-11/2.784e-11 L=220.0uH C=113.5uF R=5.01ohm
# epoch= 1400 roll(train/valid)=1.996e-08/1.929e-08 tf(train/valid)=2.728e-11/2.732e-11 L=220.0uH C=113.1uF R=5.01ohm
# epoch= 1600 roll(train/valid)=1.890e-08/1.882e-08 tf(train/valid)=2.675e-11/2.679e-11 L=220.0uH C=112.6uF R=5.00ohm
# epoch= 1800 roll(train/valid)=1.914e-08/1.845e-08 tf(train/valid)=2.626e-11/2.629e-11 L=220.0uH C=112.1uF R=5.00ohm
# epoch= 2000 roll(train/valid)=1.873e-08/1.820e-08 tf(train/valid)=2.585e-11/2.588e-11 L=220.0uH C=111.5uF R=5.01ohm
# epoch= 2200 roll(train/valid)=1.759e-08/1.763e-08 tf(train/valid)=2.514e-11/2.517e-11 L=220.0uH C=110.9uF R=5.01ohm
# epoch= 2400 roll(train/valid)=1.723e-08/1.765e-08 tf(train/valid)=2.444e-11/2.447e-11 L=220.0uH C=110.2uF R=5.00ohm
# epoch= 2600 roll(train/valid)=1.667e-08/1.698e-08 tf(train/valid)=2.374e-11/2.377e-11 L=220.0uH C=109.4uF R=5.00ohm
# epoch= 2800 roll(train/valid)=1.669e-08/1.619e-08 tf(train/valid)=2.286e-11/2.290e-11 L=220.0uH C=108.5uF R=5.00ohm
# epoch= 3000 roll(train/valid)=1.563e-08/1.559e-08 tf(train/valid)=2.192e-11/2.194e-11 L=220.0uH C=107.6uF R=5.00ohm
# epoch= 3200 roll(train/valid)=1.505e-08/1.476e-08 tf(train/valid)=2.104e-11/2.107e-11 L=220.0uH C=106.5uF R=5.00ohm
# epoch= 3400 roll(train/valid)=1.435e-08/1.391e-08 tf(train/valid)=2.009e-11/2.013e-11 L=220.0uH C=105.4uF R=5.01ohm
# epoch= 3600 roll(train/valid)=1.322e-08/1.327e-08 tf(train/valid)=1.888e-11/1.890e-11 L=220.0uH C=104.2uF R=5.00ohm
# epoch= 3800 roll(train/valid)=1.267e-08/1.257e-08 tf(train/valid)=1.767e-11/1.768e-11 L=220.0uH C=103.0uF R=5.00ohm
# epoch= 4000 roll(train/valid)=1.193e-08/1.169e-08 tf(train/valid)=1.641e-11/1.643e-11 L=220.0uH C=101.6uF R=5.00ohm
# epoch= 4200 roll(train/valid)=1.089e-08/1.075e-08 tf(train/valid)=1.502e-11/1.503e-11 L=220.0uH C=100.1uF R=5.00ohm
# epoch= 4400 roll(train/valid)=9.657e-09/9.761e-09 tf(train/valid)=1.367e-11/1.368e-11 L=220.0uH C=98.6uF R=5.00ohm
# epoch= 4600 roll(train/valid)=8.887e-09/8.693e-09 tf(train/valid)=1.228e-11/1.229e-11 L=220.0uH C=97.0uF R=5.00ohm
# epoch= 4800 roll(train/valid)=7.441e-09/7.678e-09 tf(train/valid)=1.087e-11/1.089e-11 L=220.0uH C=95.3uF R=5.00ohm
# epoch= 5000 roll(train/valid)=6.738e-09/6.465e-09 tf(train/valid)=9.382e-12/9.388e-12 L=220.0uH C=93.5uF R=5.00ohm
# epoch= 5200 roll(train/valid)=5.716e-09/5.898e-09 tf(train/valid)=8.019e-12/8.032e-12 L=220.0uH C=91.8uF R=5.00ohm
# epoch= 5400 roll(train/valid)=4.867e-09/4.706e-09 tf(train/valid)=6.673e-12/6.671e-12 L=220.0uH C=90.0uF R=5.00ohm
# epoch= 5600 roll(train/valid)=3.832e-09/3.779e-09 tf(train/valid)=5.361e-12/5.364e-12 L=220.0uH C=88.2uF R=5.00ohm
# epoch= 5800 roll(train/valid)=3.081e-09/2.932e-09 tf(train/valid)=4.264e-12/4.274e-12 L=220.0uH C=86.4uF R=5.00ohm
# epoch= 6000 roll(train/valid)=2.233e-09/2.200e-09 tf(train/valid)=3.124e-12/3.123e-12 L=220.0uH C=84.7uF R=5.00ohm
# epoch= 6200 roll(train/valid)=1.626e-09/1.612e-09 tf(train/valid)=2.289e-12/2.294e-12 L=220.0uH C=83.1uF R=5.00ohm
# epoch= 6400 roll(train/valid)=1.122e-09/1.118e-09 tf(train/valid)=1.590e-12/1.595e-12 L=220.0uH C=81.6uF R=5.00ohm
# epoch= 6600 roll(train/valid)=7.192e-10/7.288e-10 tf(train/valid)=1.032e-12/1.038e-12 L=220.0uH C=80.3uF R=5.00ohm
# epoch= 6800 roll(train/valid)=4.133e-10/4.396e-10 tf(train/valid)=6.261e-13/6.233e-13 L=220.0uH C=79.1uF R=5.00ohm
# epoch= 7000 roll(train/valid)=2.626e-10/2.647e-10 tf(train/valid)=3.814e-13/3.813e-13 L=220.0uH C=78.1uF R=5.00ohm
# epoch= 7200 roll(train/valid)=1.395e-10/1.382e-10 tf(train/valid)=2.157e-13/2.153e-13 L=220.0uH C=77.2uF R=5.00ohm
# epoch= 7400 roll(train/valid)=6.965e-11/6.849e-11 tf(train/valid)=1.155e-13/1.158e-13 L=220.0uH C=76.6uF R=5.00ohm
# epoch= 7600 roll(train/valid)=3.249e-11/3.183e-11 tf(train/valid)=6.484e-14/6.553e-14 L=220.0uH C=76.1uF R=5.00ohm
# epoch= 7800 roll(train/valid)=1.288e-11/1.252e-11 tf(train/valid)=4.043e-14/4.078e-14 L=220.0uH C=75.7uF R=5.00ohm
# epoch= 8000 roll(train/valid)=5.923e-12/6.002e-12 tf(train/valid)=2.736e-14/2.735e-14 L=220.0uH C=75.4uF R=5.00ohm
# L_hat=2.200003e-04, C_hat=7.543847e-05, R_hat=5.000073e+00

# %%
# --- 学習の可視化（損失とパラメータ）---
fig_loss, ax = plt.subplots(1, 1, figsize=(12, 5))

x_axis = np.arange(len(loss_history["train_roll"])) * log_every
ax.plot(x_axis, loss_history["train_roll"], label="train rollout", linewidth=2)
ax.plot(x_axis, loss_history["valid_roll"], label="valid rollout", linewidth=2)
ax.plot(
    x_axis,
    loss_history["train_tf"],
    label="train teacher forcing",
    linewidth=1,
    alpha=0.6,
)
ax.plot(
    x_axis,
    loss_history["valid_tf"],
    label="valid teacher forcing",
    linewidth=1,
    alpha=0.6,
)
ax.set_yscale("log")
ax.set_xlabel("epoch")
ax.set_ylabel("MSE")
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_title("Buck loss transition")
plt.tight_layout()
plt.show()

if keep_log:
    save_figure_to_log(fig_loss, "buck_loss_transition", result_dir, "Buck 損失遷移")

fig_param, _ = plot_param_learning_progress(
    param_history=param_history,
    L_true=float(params.L_true),
    C_true=float(params.C_true),
    R_true=float(params.R_true),
    epochs=len(param_history["L"]),
)
plt.show()

if keep_log:
    save_figure_to_log(
        fig_param, "buck_param_learning", result_dir, "Buck パラメータ推定の推移"
    )

# %%
# --- Buck: 区間ごとに full roll-out して比較（train/valid/test）---
@torch.no_grad()
def rollout_and_compare(
    split_name: str,
    t_series: np.ndarray,  # [N+1]
    h_meas_series_local: torch.Tensor,  # [N+1,2]
    x_steps_local: torch.Tensor,  # [N,3]
    N_cycles: float = 4.0,
) -> torch.Tensor:
    cell.eval()
    h0 = h_meas_series_local[:1]  # [1,2]
    h_pred_series = rollout_full_series(
        cell, h0_1x2=h0, x_steps=x_steps_local
    )  # [N+1,2]

    h_meas_np = h_meas_series_local.detach().cpu().numpy()
    h_pred_np = h_pred_series.detach().cpu().numpy()

    fig, _ = plot_compare_tail(
        t1=t_series,
        iL1=h_meas_np[:, 0],
        vC1=h_meas_np[:, 1],
        label1=f"meas({split_name})",
        t2=t_series,
        iL2=h_pred_np[:, 0],
        vC2=h_pred_np[:, 1],
        label2=f"buck_roll({split_name})",
        T=float(params.T),
        N_cycles=float(N_cycles),
        title=f"Buck roll-out vs meas ({split_name})",
    )
    plt.show()

    if keep_log:
        save_figure_to_log(
            fig,
            f"buck_rollout_{split_name}",
            result_dir,
            f"Buck rollout比較({split_name})",
        )

    # rollout MSE（steps で評価）
    mse_steps = (
        nn.functional.mse_loss(h_pred_series[:-1], h_meas_series_local[:-1])
        .detach()
        .cpu()
        .item()
    )
    print(f"{split_name}: rollout MSE(steps)={mse_steps:.6e}")
    return h_pred_series


# series の切り出し（x_* は steps 長）
t_train_series = t_raw[: train_steps + 1]
t_valid_series = t_raw[train_steps : train_steps + valid_steps + 1]
t_test_series = t_raw[train_steps + valid_steps :]

h_meas_train_series = h_meas_series[: train_steps + 1]
h_meas_valid_series = h_meas_series[train_steps : train_steps + valid_steps + 1]
h_meas_test_series = h_meas_series[train_steps + valid_steps :]

h_buck_train_series = rollout_and_compare(
    "train", t_train_series, h_meas_train_series, x_train, N_cycles=2
)
h_buck_valid_series = rollout_and_compare(
    "valid", t_valid_series, h_meas_valid_series, x_valid, N_cycles=2
)
h_buck_test_series = rollout_and_compare(
    "test", t_test_series, h_meas_test_series, x_test, N_cycles=4
)
# Out:
# train: rollout MSE(steps)=1.328006e-11
# valid: rollout MSE(steps)=1.184785e-11
# test: rollout MSE(steps)=8.651049e-12

# %%
# --- GRU 用: 無次元化スケールの定義（特に dt）---
@dataclass(frozen=True)
class Scales:
    Vin: float
    Vref: float
    I_base: float
    f_sw: float


# I_base は train 区間の電流スケール（0割防止）
iL_train_np = h_meas_train_series[:, 0].detach().cpu().numpy()
I_base = float(np.maximum(np.mean(np.abs(iL_train_np)), 1e-3))

scales = Scales(
    Vin=float(params.Vin),
    Vref=float(params.Vref),
    I_base=I_base,
    f_sw=float(params.f_sw),
)
print(scales)


def scale_h(h: torch.Tensor, scales_: Scales) -> torch.Tensor:
    """h=[iL,vC] を無次元化"""
    out = torch.empty_like(h)
    out[:, 0] = h[:, 0] / float(scales_.I_base)
    out[:, 1] = h[:, 1] / float(scales_.Vref)
    return out


def scale_x(x: torch.Tensor, scales_: Scales) -> torch.Tensor:
    """x=[vs,u,dt] を無次元化（uはそのまま）"""
    out = torch.empty_like(x)
    out[:, 0] = x[:, 0] / float(scales_.Vin)
    out[:, 1] = x[:, 1]
    out[:, 2] = x[:, 2] * float(scales_.f_sw)  # dt/T 相当
    return out


def scale_noise(noise: torch.Tensor, scales_: Scales) -> torch.Tensor:
    """noise=[iL_noise,vC_noise] を無次元化"""
    out = torch.empty_like(noise)
    out[:, 0] = noise[:, 0] / float(scales_.I_base)
    out[:, 1] = noise[:, 1] / float(scales_.Vref)
    return out
# Out:
# Scales(Vin=10.0, Vref=5.0, I_base=0.999944269657135, f_sw=100000.0)

# %%
# --- GRU 用データ作成（残差 = meas - buck_rollout）---
# steps に揃える（長さ N_split）
h_buck_train_steps = h_buck_train_series[:-1]
h_buck_valid_steps = h_buck_valid_series[:-1]
h_buck_test_steps = h_buck_test_series[:-1]

noise_train_steps = h_meas_train_steps - h_buck_train_steps
noise_valid_steps = h_meas_valid_steps - h_buck_valid_steps
noise_test_steps = h_meas_test_steps - h_buck_test_steps

# 無次元化
h_train_scaled = scale_h(h_meas_train_steps, scales)
x_train_scaled = scale_x(x_train, scales)
noise_train_scaled = scale_noise(noise_train_steps, scales)

h_valid_scaled = scale_h(h_meas_valid_steps, scales)
x_valid_scaled = scale_x(x_valid, scales)
noise_valid_scaled = scale_noise(noise_valid_steps, scales)

h_test_scaled = scale_h(h_meas_test_steps, scales)
x_test_scaled = scale_x(x_test, scales)
noise_test_scaled = scale_noise(noise_test_steps, scales)


def create_sequences_scaled(
    h_scaled: torch.Tensor,  # [N,2]
    x_scaled: torch.Tensor,  # [N,3]
    noise_scaled: torch.Tensor,  # [N,2]
    seq_len: int,
) -> tuple[torch.Tensor, torch.Tensor]:
    """GRU 入力系列を作成

    入力特徴量（各時刻）: [iL, vC, vs, u, dt, iL_noise_prev, vC_noise_prev] (7次元)
    出力（教師）: 次時刻の noise [iL_noise, vC_noise]
    """
    if seq_len <= 0:
        raise ValueError("seq_len must be positive")

    N_local = int(h_scaled.shape[0])
    if N_local <= seq_len:
        raise ValueError("series is too short for seq_len")

    X_list: list[torch.Tensor] = []
    y_list: list[torch.Tensor] = []

    for i in range(N_local - seq_len):
        seq_frames: list[torch.Tensor] = []
        for j in range(seq_len):
            idx = i + j
            state_and_in = torch.cat([h_scaled[idx], x_scaled[idx]], dim=0)  # 5
            noise_prev = (
                noise_scaled[idx - 1]
                if idx > 0
                else torch.zeros(2, device=h_scaled.device)
            )
            frame = torch.cat([state_and_in, noise_prev], dim=0)  # 7
            seq_frames.append(frame)

        X_list.append(torch.stack(seq_frames, dim=0))
        y_list.append(noise_scaled[i + seq_len])

    return torch.stack(X_list, dim=0), torch.stack(y_list, dim=0)


X_train_seq, y_train_seq = create_sequences_scaled(
    h_train_scaled, x_train_scaled, noise_train_scaled, seq_len=int(params.seq_length)
)
X_valid_seq, y_valid_seq = create_sequences_scaled(
    h_valid_scaled, x_valid_scaled, noise_valid_scaled, seq_len=int(params.seq_length)
)
X_test_seq, y_test_seq = create_sequences_scaled(
    h_test_scaled, x_test_scaled, noise_test_scaled, seq_len=int(params.seq_length)
)

print(f"X_train_seq={tuple(X_train_seq.shape)} y_train_seq={tuple(y_train_seq.shape)}")
print(f"X_valid_seq={tuple(X_valid_seq.shape)} y_valid_seq={tuple(y_valid_seq.shape)}")
print(f"X_test_seq={tuple(X_test_seq.shape)} y_test_seq={tuple(y_test_seq.shape)}")
print(f"input_size={int(X_train_seq.shape[2])}")
# Out:
# X_train_seq=(990, 10, 7) y_train_seq=(990, 2)
# X_valid_seq=(490, 10, 7) y_valid_seq=(490, 2)
# X_test_seq=(490, 10, 7) y_test_seq=(490, 2)
# input_size=7

# %%
# --- GRU学習データ（入力特徴量）を全体表示（note3と同様）---
# X_train_seq: [N_samples, seq_len, 7]（無次元化済み）
X_train_seq_np: np.ndarray = X_train_seq.detach().cpu().numpy()

# 入力特徴量名（note4のスケーリング仕様に合わせて表記）
feature_names: list[str] = [
    "iL/I_base",
    "vC/Vref",
    "vs/Vin",
    "u",
    "dt*f_sw",
    "iL_noise_prev/I_base",
    "vC_noise_prev/Vref",
]
feature_units: list[str] = ["[-]", "[-]", "[-]", "[-]", "[-]", "[-]", "[-]"]

# 各系列サンプルの「最後の時刻」の特徴量を並べる（note3と同じ）
last_timestep_features: np.ndarray = X_train_seq_np[:, -1, :]  # [N_samples, 7]

# time_axis（最後時刻に対応させる）
# train区間の時刻は t_train_series: [train_steps+1]
# サンプルiの最後時刻は (i+seq_len-1)番目のstep
n_samples: int = int(last_timestep_features.shape[0])
time_axis_us: np.ndarray = (
    t_train_series[(params.seq_length - 1) : (params.seq_length - 1 + n_samples)] * 1e6
)

# 重いときは stride を上げる（例: 10, 50）
stride: int = 1

fig, axs = plt.subplots(7, 1, figsize=(14, 12), sharex=True)
for i in range(7):
    axs[i].plot(
        time_axis_us[::stride],
        last_timestep_features[::stride, i],
        linewidth=1.0,
        alpha=0.7,
    )
    axs[i].set_ylabel(f"{feature_names[i]} {feature_units[i]}", fontsize=11)
    axs[i].grid(True, alpha=0.3)
    axs[i].set_title(
        f"GRU Training Data (note4): {feature_names[i]} (Value at Last Time Step)",
        fontsize=12,
        fontweight="bold",
    )

axs[6].set_xlabel("Time [μs]", fontsize=12)
plt.tight_layout()
plt.show()

if keep_log:
    save_figure_to_log(
        fig, "gru_training_data_features", result_dir, "GRU 学習データ（特徴量・全体）"
    )

# %%
# --- GRU 学習（残差予測）---
gru_model = GRUModel(
    input_size=int(X_train_seq.shape[2]),
    hidden_size=32,
    num_layers=2,
    output_size=2,
    seq_length=int(params.seq_length),
).to(device)

gru_optimizer = optim.Adam(gru_model.parameters(), lr=float(params.gru_lr))
gru_loss_fn = nn.MSELoss()

loss_gru: dict[str, list[float]] = {"train": [], "valid": []}

for epoch in range(1, int(params.epochs_gru) + 1):
    gru_model.train()
    gru_optimizer.zero_grad(set_to_none=True)

    pred_train = gru_model(X_train_seq)
    train_loss = gru_loss_fn(pred_train, y_train_seq)
    train_loss.backward()
    gru_optimizer.step()

    gru_model.eval()
    with torch.no_grad():
        pred_valid = gru_model(X_valid_seq)
        valid_loss = gru_loss_fn(pred_valid, y_valid_seq)

    loss_gru["train"].append(float(train_loss.detach().cpu().item()))
    loss_gru["valid"].append(float(valid_loss.detach().cpu().item()))

    if epoch % 50 == 0 or epoch == 1:
        print(
            f"epoch={epoch:4d} train={loss_gru['train'][-1]:.3e} "
            f"valid={loss_gru['valid'][-1]:.3e}"
        )

# test
gru_model.eval()
with torch.no_grad():
    pred_test = gru_model(X_test_seq)
    test_loss = gru_loss_fn(pred_test, y_test_seq).detach().cpu().item()

print(f"GRU test loss={test_loss:.3e}")

# 損失の遷移
fig_gru, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(loss_gru["train"], label="train", linewidth=2)
ax.plot(loss_gru["valid"], label="valid", linewidth=2)
ax.set_yscale("log")
ax.set_xlabel("epoch")
ax.set_ylabel("MSE")
ax.grid(True, alpha=0.3)
ax.legend()
ax.set_title("GRU loss transition")
plt.tight_layout()
plt.show()

if keep_log:
    save_figure_to_log(fig_gru, "gru_loss_transition", result_dir, "GRU 損失遷移")
    save_text_output(
        result_dir, text=f"GRU test loss={test_loss:.6e}\n", title="GRU 評価"
    )
# Out:
# epoch=   1 train=1.803e-02 valid=9.530e-03
# epoch=  50 train=7.345e-06 valid=1.499e-06
# epoch= 100 train=7.248e-07 valid=6.266e-07
# epoch= 150 train=4.758e-07 valid=4.722e-07
# epoch= 200 train=4.356e-07 valid=4.328e-07
# epoch= 250 train=4.003e-07 valid=3.982e-07
# epoch= 300 train=3.679e-07 valid=3.661e-07
# GRU test loss=3.685e-07

# %%
# --- Buck + GRU 合成（test）---
@torch.no_grad()
def unscale_noise(noise_scaled: torch.Tensor, scales_: Scales) -> torch.Tensor:
    out = torch.empty_like(noise_scaled)
    out[:, 0] = noise_scaled[:, 0] * float(scales_.I_base)
    out[:, 1] = noise_scaled[:, 1] * float(scales_.Vref)
    return out


seq_len: int = int(params.seq_length)

# pred_test は「noise_scaled」の予測（shape [N_test-seq_len, 2]）
noise_pred_test_scaled: torch.Tensor = pred_test
noise_pred_test: torch.Tensor = unscale_noise(noise_pred_test_scaled, scales)

# steps 系列にそろえる
t_test_steps = t_test_series[:-1]  # [N_test]
h_meas_test_np = h_meas_test_steps.detach().cpu().numpy()  # [N_test,2]
h_buck_test_np = h_buck_test_steps.detach().cpu().numpy()  # [N_test,2]

noise_pred_test_np = noise_pred_test.detach().cpu().numpy()  # [N_test-seq_len,2]

# 合成できる区間（seq_len 以降）
idx0: int = seq_len
idx1: int = seq_len + int(noise_pred_test_np.shape[0])

t_view = t_test_steps[idx0:idx1]

iL_meas_view = h_meas_test_np[idx0:idx1, 0]
vC_meas_view = h_meas_test_np[idx0:idx1, 1]

iL_buck_view = h_buck_test_np[idx0:idx1, 0]
vC_buck_view = h_buck_test_np[idx0:idx1, 1]

iL_gru_view = noise_pred_test_np[:, 0]
vC_gru_view = noise_pred_test_np[:, 1]

# note3と同様の 4段プロット（Measured / Buck / GRU / Sum）
fig_iL, _, fig_vC, _ = plot_buck_gru_components_tail(
    t=t_view,
    iL_meas=iL_meas_view,
    vC_meas=vC_meas_view,
    iL_buck=iL_buck_view,
    vC_buck=vC_buck_view,
    iL_gru=iL_gru_view,
    vC_gru=vC_gru_view,
    T=float(params.T),
    N_cycles=4.0,
    title="note4 (test)",
)
plt.show()

if keep_log:
    save_figure_to_log(
        fig_iL,
        "tail4T_iL_meas_buck_gru_sum",
        result_dir,
        "iL: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )
    save_figure_to_log(
        fig_vC,
        "tail4T_vC_meas_buck_gru_sum",
        result_dir,
        "vC: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )

# 数値評価（同区間）
h_sum_test = np.stack([iL_buck_view + iL_gru_view, vC_buck_view + vC_gru_view], axis=1)

mse_buck = float(np.mean((h_buck_test_np[idx0:idx1] - h_meas_test_np[idx0:idx1]) ** 2))
mse_sum = float(np.mean((h_sum_test - h_meas_test_np[idx0:idx1]) ** 2))
print(f"MSE buck={mse_buck:.6e} -> buck+gru={mse_sum:.6e}")

if keep_log:
    save_text_output(
        result_dir,
        text=f"MSE buck={mse_buck:.6e}\nMSE buck+gru={mse_sum:.6e}\n",
        title="Buck+GRU 評価(test)",
    )
# Out:
# MSE buck=8.811593e-12 -> buck+gru=8.608980e-06

# %%
# --- ログ用: 回路パラメータを比較しやすい形で保存（推論後に追記）---
if keep_log:
    summary_lines: list[str] = []
    summary_lines.append("【回路パラメータ】")
    summary_lines.append(
        "  真の値: "
        f"L = {float(params.L_true):.6e} [H], "
        f"C = {float(params.C_true):.6e} [F], "
        f"R = {float(params.R_true):.3f} [Ω]"
    )
    summary_lines.append(
        "  初期値: "
        f"L = {float(params.L_init):.6e} [H], "
        f"C = {float(params.C_init):.6e} [F], "
        f"R = {float(params.R_init):.3f} [Ω]"
    )
    summary_lines.append(
        "  推論値: "
        f"L = {float(L_hat):.6e} [H], "
        f"C = {float(C_hat):.6e} [F], "
        f"R = {float(R_hat):.3f} [Ω]"
    )

    save_text_output(result_dir, text="\n".join(summary_lines), title="Summary")
