# %% [markdown]
# # note4

# %% [markdown]
# - ノイズ除去はしない
# - BuckConverterCell の学習は、過渡状態を含めた全データの最初から 100 周期、1 周期あたり 20 プロット
# - GRU はこれまで通り定常 10 周期、1 周期あたり 200 プロット
#   - ノイズを的確に学習するために 1 周期だけにして 2000 プロットとかもありかも
# - 一旦 BuckConverterCell で正しくパラメータ推論することを目標にする

# %%
from dataclasses import asdict, dataclass

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from scipy.signal import filtfilt, firwin
from torch import nn, optim

from src.utils.load_data import path_list
from src.utils.models import BuckConverterCell, GRUModel
from src.utils.plot_data import (
    plot_buck_gru_components_tail,
    plot_compare_tail,
    plot_iLvC,
    plot_param_learning_progress,
    plot_u_vs_iL_vC,
)
from src.utils.save_log import (
    create_result_dir,
    init_log,
    save_figure_to_log,
)

# 乱数固定用の処理
seed = 10
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)

# %%
keep_log: bool = True
keep_log: bool = False


@dataclass(frozen=True)
class Params:
    data_path: str = path_list.path2  # 実機

    # 真値パラメータ
    L_true: float = 223.6e-6
    C_true: float = 73.8e-6
    R_true: float = 5
    L_init = 200e-6
    C_init = 100e-6
    R_init = 8.0

    Vin: int = 10
    # Vref: int = 5
    # duty: float = Vref / Vin
    f_sw: float = 1e5  # スイッチング周波数
    T: float = 1 / f_sw  # 1周期の実時間
    cycles: int = 10
    cycles_sim: int = 1000  # この周期数分シミュレーションすれば定常であるとする
    samples_per_cycle: int = 200

    train_ratio = 0.3
    valid_ratio = 0.3
    # test_ratio = 1 - train_ratio - valid_ratio

    numtaps = 1001  # FIR長（奇数）

    clipped_k: float = 2.0

    # 学習パラメータ

    # 異なるパラメータに異なる学習率を設定
    lr_l = 5e-2
    lr_c = 1e-2
    lr_r = 2e-2

    epochs = 10000

    # GRU学習用のデータ準備（時系列データ）
    seq_length = 10

    gru_lr = 0.001
    gru_epochs = 200


params = Params()

# %%
# ログ保存の初期化
if keep_log:
    result_dir = create_result_dir(
        "note4",
        base_dir="results/actual",
        config_dict=asdict(params),
    )
    log_path = init_log(result_dir, "actual_machine_notebooks/note4/note.ipynb")

# %% [markdown]
# # BuckConverterCell

# %% [markdown]
# ## 前処理

# %%
# データの読み込み
df = pd.read_csv(params.data_path, skiprows=20)

mask: np.ndarray = df["TIME"].to_numpy(dtype=np.float64) >= -0.000080
t_raw_full: np.ndarray = df.loc[mask, "TIME"].to_numpy(dtype=np.float64)  # 秒
t_raw: np.ndarray = t_raw_full - t_raw_full[0]
iL_raw: np.ndarray = df.loc[mask, "CH2"].to_numpy(dtype=np.float64)  # A
vC_raw: np.ndarray = df.loc[mask, "CH1"].to_numpy(dtype=np.float64)  # V


print(f"{len(t_raw)=}")
print(f"{len(iL_raw)=}")
print(f"{len(vC_raw)=}")

fig_list = plot_iLvC(
    t_raw,
    iL_raw,
    vC_raw,
    T=params.T,
    title="Actual Machine Data",
    show_tail=(10, 1),
    plot_style="scatter",  # 点で描画
    marker=".",
    markersize=2.0,
)

if keep_log:
    for i, (fig, _) in enumerate(fig_list):
        save_figure_to_log(
            fig,
            f"実機データ(加工前)_{i}",
            result_dir,
            "実機データ(加工前)" if i == 0 else None,
        )
# Out:
# len(t_raw)=903625
# len(iL_raw)=903625
# len(vC_raw)=903625

# %%
# FIRフィルター
fs_raw = 1.0 / np.mean(np.diff(t_raw))
fc = 0.2 * params.f_sw
b = firwin(params.numtaps, fc, fs=fs_raw)
iL_filt = filtfilt(b, [1.0], iL_raw)
vC_filt = filtfilt(b, [1.0], vC_raw)

# %%
# Duty
window = t_raw > t_raw[-1] - params.T * 10
Vref: float = float(np.mean(vC_raw[window]))
duty: float = Vref / params.Vin

# スイッチング信号
duty_phase = (t_raw[:-1] % params.T) / params.T
u_raw = (duty_phase < duty).astype(int)

# 入力電圧
vs_raw = np.ones(len(t_raw) - 1) * params.Vin

# %%
# 先頭から 100 周期分を切り出し、1周期あたり 20 プロットにダウンサンプリング
mask = (t_raw > params.T * 5) & (t_raw <= params.T * 100)
t_buck = t_raw[mask]
downsample_step = len(t_buck) // (95 * 100)
t_buck = t_buck[::downsample_step]
iL_buck = iL_filt[mask][::downsample_step]
vC_buck = vC_filt[mask][::downsample_step]
u_buck = u_raw[mask[1:]][::downsample_step]
vs_buck = vs_raw[mask[1:]][::downsample_step]

u_buck = u_buck[1:]
vs_buck = vs_buck[1:]

print(f"{len(t_buck)=}")
print(f"{len(iL_buck)=}")
print(f"{len(vC_buck)=}")
print(f"{len(u_buck)=}")
print(f"{len(vs_buck)=}")

fig, ax = plot_u_vs_iL_vC(
    t_buck,
    u_buck,
    vs_buck,
    iL_buck,
    vC_buck,
    params.T,
)

if keep_log:
    save_figure_to_log(
        fig, "BuckConverterCellの入力波形", result_dir, "BuckConverterCellの入力波形"
    )
# Out:
# len(t_buck)=9501
# len(iL_buck)=9501
# len(vC_buck)=9501
# len(u_buck)=9500
# len(vs_buck)=9500

# %%
# train, valid, test の分割
dt = np.diff(t_buck)

# numpy配列をテンソルに変換
dt_tensor = torch.tensor(dt, dtype=torch.float32)
u_tensor = torch.tensor(u_buck, dtype=torch.float32)
vs_tensor = torch.tensor(vs_buck, dtype=torch.float32)
iL_buck_tensor = torch.tensor(iL_buck.copy(), dtype=torch.float32)
vC_buck_tensor = torch.tensor(vC_buck.copy(), dtype=torch.float32)

# train
train_len = int(len(dt) * params.train_ratio)

t_train = t_buck[: train_len + 1]
dt_train = dt_tensor[:train_len]
u_train = u_tensor[:train_len]
vs_train = vs_tensor[:train_len]
iL_buck_train = iL_buck_tensor[: train_len + 1]
vC_buck_train = vC_buck_tensor[: train_len + 1]

h_buck_train = torch.stack([iL_buck_train[:-1], vC_buck_train[:-1]], dim=1)
x_train = torch.stack([vs_train, u_train, dt_train], dim=1)
target_buck_train = torch.stack([iL_buck_train[1:], vC_buck_train[1:]], dim=1)


# valid
valid_len = int(len(dt) * params.valid_ratio)

t_valid = t_buck[train_len : train_len + valid_len]
dt_valid = dt_tensor[train_len : train_len + valid_len]
u_valid = u_tensor[train_len : train_len + valid_len]
vs_valid = vs_tensor[train_len : train_len + valid_len]
iL_buck_valid = iL_buck_tensor[train_len : train_len + valid_len + 1]
vC_buck_valid = vC_buck_tensor[train_len : train_len + valid_len + 1]

h_buck_valid = torch.stack([iL_buck_valid[:-1], vC_buck_valid[:-1]], dim=1)
x_valid = torch.stack([vs_valid, u_valid, dt_valid], dim=1)
target_buck_valid = torch.stack([iL_buck_valid[1:], vC_buck_valid[1:]], dim=1)

# test
t_test = t_buck[train_len + valid_len :]
dt_test = dt_tensor[train_len + valid_len :]
u_test = u_tensor[train_len + valid_len :]
vs_test = vs_tensor[train_len + valid_len :]
iL_buck_test = iL_buck_tensor[train_len + valid_len :]
vC_buck_test = vC_buck_tensor[train_len + valid_len :]

h_buck_test = torch.stack([iL_buck_test[:-1], vC_buck_test[:-1]], dim=1)
x_test = torch.stack([vs_test, u_test, dt_test], dim=1)
target_buck_test = torch.stack([iL_buck_test[1:], vC_buck_test[1:]], dim=1)

print(f"{h_buck_train.shape=}")
print(f"{x_train.shape=}")
print(f"{target_buck_train.shape=}")

print(f"{h_buck_valid.shape=}")
print(f"{x_valid.shape=}")
print(f"{target_buck_valid.shape=}")

print(f"{h_buck_test.shape=}")
print(f"{x_test.shape=}")
print(f"{target_buck_test.shape=}")
# Out:
# h_buck_train.shape=torch.Size([2850, 2])
# x_train.shape=torch.Size([2850, 3])
# target_buck_train.shape=torch.Size([2850, 2])
# h_buck_valid.shape=torch.Size([2850, 2])
# x_valid.shape=torch.Size([2850, 3])
# target_buck_valid.shape=torch.Size([2850, 2])
# h_buck_test.shape=torch.Size([3800, 2])
# x_test.shape=torch.Size([3800, 3])
# target_buck_test.shape=torch.Size([3800, 2])

# %% [markdown]
# ## 学習

# %%
buck_converter_cell = BuckConverterCell(
    L_init=params.L_init,
    C_init=params.C_init,
    R_init=params.R_init,
)

optimizer = optim.Adam(
    [
        {"params": [buck_converter_cell.log_L], "lr": params.lr_l},
        {"params": [buck_converter_cell.log_C], "lr": params.lr_c},
        {"params": [buck_converter_cell.log_R], "lr": params.lr_r},
    ]
)

loss_fn = nn.MSELoss()
# loss_fn = nn.SmoothL1Loss(beta=0.1)

# 損失履歴を保存
loss_history = {"train": [], "valid": []}
param_history = {"L": [], "C": [], "R": []}

# 学習ループ
for epoch in range(params.epochs):
    # 学習モード
    buck_converter_cell.train()
    optimizer.zero_grad()
    h_pred_train = buck_converter_cell(h_buck_train, x_train)
    train_loss = loss_fn(h_pred_train, target_buck_train)
    train_loss.backward()
    optimizer.step()

    loss_history["train"].append(train_loss.item())

    # 検証モード（勾配計算なし）
    buck_converter_cell.eval()
    with torch.no_grad():
        h_pred_valid = buck_converter_cell(h_buck_valid, x_valid)
        valid_loss = loss_fn(h_pred_valid, target_buck_valid)
        loss_history["valid"].append(valid_loss.item())

    # パラメータの履歴を保存
    param_history["L"].append(buck_converter_cell.log_L.exp().item())
    param_history["C"].append(buck_converter_cell.log_C.exp().item())
    param_history["R"].append(buck_converter_cell.log_R.exp().item())

    if epoch % 50 == 0:
        output_line = (
            f"Epoch {epoch}: Train Loss={train_loss.item():.6e}, "
            f"Valid Loss={valid_loss.item():.6e}\n"
            f"  L={buck_converter_cell.log_L.exp().item() * 1e6:.1f}µH "
            f"(true={params.L_true * 1e6:.1f})"
            f"C={buck_converter_cell.log_C.exp().item() * 1e6:.1f}µF "
            f"(true={params.C_true * 1e6:.1f})"
            f"R={buck_converter_cell.log_R.exp().item():.2f}Ω "
            f"(true={params.R_true:.1f})"
        )
        print(output_line)

# テストデータでの評価
buck_converter_cell.eval()
with torch.no_grad():
    h_pred_test = buck_converter_cell(h_buck_test, x_test)
    test_loss = loss_fn(h_pred_test, target_buck_test)

print(f"Final test loss: {test_loss.item():.6e}")
# Out:
# Epoch 0: Train Loss=1.395520e-06, Valid Loss=1.248899e-06
#   L=210.2µH (true=223.6)C=99.0µF (true=73.8)R=8.12Ω (true=5.0)
# Epoch 50: Train Loss=7.373698e-07, Valid Loss=6.650034e-07
#   L=327.2µH (true=223.6)C=66.3µF (true=73.8)R=4.47Ω (true=5.0)
# Epoch 100: Train Loss=7.130433e-07, Valid Loss=8.428270e-07
#   L=336.4µH (true=223.6)C=51.9µF (true=73.8)R=3.62Ω (true=5.0)
# Epoch 150: Train Loss=7.129463e-07, Valid Loss=8.209487e-07
#   L=337.4µH (true=223.6)C=52.6µF (true=73.8)R=3.66Ω (true=5.0)
# Epoch 200: Train Loss=7.129447e-07, Valid Loss=8.228211e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 250: Train Loss=7.129480e-07, Valid Loss=8.227447e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 300: Train Loss=7.129480e-07, Valid Loss=8.227443e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 350: Train Loss=7.129480e-07, Valid Loss=8.227443e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 400: Train Loss=7.129481e-07, Valid Loss=8.227432e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 450: Train Loss=7.129481e-07, Valid Loss=8.227429e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 500: Train Loss=7.129478e-07, Valid Loss=8.227425e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 550: Train Loss=7.129476e-07, Valid Loss=8.227425e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 600: Train Loss=7.129481e-07, Valid Loss=8.227429e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 650: Train Loss=7.129478e-07, Valid Loss=8.227425e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 700: Train Loss=7.129476e-07, Valid Loss=8.227425e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 750: Train Loss=7.129480e-07, Valid Loss=8.227419e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 800: Train Loss=7.129476e-07, Valid Loss=8.227413e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 850: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 900: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 950: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1000: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1050: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1100: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1150: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1200: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1250: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1300: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1350: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1400: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1450: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1500: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1550: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1600: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1650: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1700: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1750: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1800: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1850: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1900: Train Loss=7.129476e-07, Valid Loss=8.227411e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 1950: Train Loss=7.129477e-07, Valid Loss=8.227388e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2000: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2050: Train Loss=7.129474e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2100: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2150: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2200: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2250: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2300: Train Loss=7.129474e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2350: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2400: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2450: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2500: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2550: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2600: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2650: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2700: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2750: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2800: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2850: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2900: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 2950: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3000: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3050: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3100: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3150: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3200: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3250: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3300: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3350: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3400: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3450: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3500: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3550: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3600: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3650: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3700: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3750: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3800: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3850: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3900: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 3950: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4000: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4050: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4100: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4150: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4200: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4250: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4300: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4350: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4400: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4450: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4500: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4550: Train Loss=7.129474e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4600: Train Loss=7.129474e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4650: Train Loss=7.129474e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4700: Train Loss=7.129474e-07, Valid Loss=8.227389e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4750: Train Loss=7.129472e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4800: Train Loss=7.129474e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4850: Train Loss=7.129477e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4900: Train Loss=7.129476e-07, Valid Loss=8.227388e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 4950: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5000: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5050: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5100: Train Loss=7.129476e-07, Valid Loss=8.227388e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5150: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5200: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5250: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5300: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5350: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5400: Train Loss=7.129477e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5450: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5500: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5550: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5600: Train Loss=7.129477e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5650: Train Loss=7.129474e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5700: Train Loss=7.129472e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5750: Train Loss=7.129474e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5800: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5850: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5900: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 5950: Train Loss=7.129474e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6000: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6050: Train Loss=7.129474e-07, Valid Loss=8.227389e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6100: Train Loss=7.129472e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6150: Train Loss=7.129473e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6200: Train Loss=7.129477e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6250: Train Loss=7.129474e-07, Valid Loss=8.227389e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6300: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6350: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6400: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6450: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6500: Train Loss=7.129474e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6550: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6600: Train Loss=7.129476e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6650: Train Loss=7.129476e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6700: Train Loss=7.129477e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6750: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6800: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6850: Train Loss=7.129473e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6900: Train Loss=7.129476e-07, Valid Loss=8.227389e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 6950: Train Loss=7.129478e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7000: Train Loss=7.129476e-07, Valid Loss=8.227392e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7050: Train Loss=7.129469e-07, Valid Loss=8.227387e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7100: Train Loss=7.129474e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7150: Train Loss=7.129476e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7200: Train Loss=7.129474e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7250: Train Loss=7.129480e-07, Valid Loss=8.227383e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7300: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7350: Train Loss=7.129477e-07, Valid Loss=8.227393e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7400: Train Loss=7.129473e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7450: Train Loss=7.129477e-07, Valid Loss=8.227395e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7500: Train Loss=7.129478e-07, Valid Loss=8.227394e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7550: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7600: Train Loss=7.129483e-07, Valid Loss=8.227375e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7650: Train Loss=7.129476e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7700: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7750: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7800: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7850: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7900: Train Loss=7.129477e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 7950: Train Loss=7.129477e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8000: Train Loss=7.129477e-07, Valid Loss=8.227370e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8050: Train Loss=7.129489e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8100: Train Loss=7.129476e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8150: Train Loss=7.129476e-07, Valid Loss=8.227385e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8200: Train Loss=7.129476e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8250: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8300: Train Loss=7.129476e-07, Valid Loss=8.227385e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8350: Train Loss=7.129477e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8400: Train Loss=7.129469e-07, Valid Loss=8.227374e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8450: Train Loss=7.129480e-07, Valid Loss=8.227370e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8500: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8550: Train Loss=7.129473e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8600: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8650: Train Loss=7.129476e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8700: Train Loss=7.129473e-07, Valid Loss=8.227383e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8750: Train Loss=7.129476e-07, Valid Loss=8.227383e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8800: Train Loss=7.129476e-07, Valid Loss=8.227379e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8850: Train Loss=7.129469e-07, Valid Loss=8.227370e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8900: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 8950: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9000: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9050: Train Loss=7.129473e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9100: Train Loss=7.129476e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9150: Train Loss=7.129476e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9200: Train Loss=7.129473e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9250: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9300: Train Loss=7.129483e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9350: Train Loss=7.129478e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9400: Train Loss=7.129476e-07, Valid Loss=8.227385e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9450: Train Loss=7.129483e-07, Valid Loss=8.227382e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9500: Train Loss=7.129478e-07, Valid Loss=8.227381e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9550: Train Loss=7.129487e-07, Valid Loss=8.227405e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9600: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9650: Train Loss=7.129473e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9700: Train Loss=7.129474e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9750: Train Loss=7.129476e-07, Valid Loss=8.227379e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9800: Train Loss=7.129477e-07, Valid Loss=8.227381e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9850: Train Loss=7.129477e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9900: Train Loss=7.129468e-07, Valid Loss=8.227391e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Epoch 9950: Train Loss=7.129476e-07, Valid Loss=8.227390e-07
#   L=337.4µH (true=223.6)C=52.5µF (true=73.8)R=3.65Ω (true=5.0)
# Final test loss: 9.024007e-07

# %% [markdown]
# ## 結果確認

# %%
# Lossの遷移をグラフ表示
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

epochs_list = range(1, params.epochs + 1)
ax.plot(epochs_list, loss_history["train"], label="Train Loss", linewidth=2, alpha=0.8)
ax.plot(epochs_list, loss_history["valid"], label="Valid Loss", linewidth=2, alpha=0.8)

ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss (MSE)", fontsize=12)
ax.set_title("Loss Transition", fontsize=14, fontweight="bold")
ax.set_yscale("log")
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(
        fig,
        "BuckConverterCellの学習結果_Lossの遷移",
        result_dir,
        "BuckConverterCellの学習結果_Lossの遷移",
    )

# %%
# 回路パラメータの学習による変化をグラフ表示
fig, ax = plot_param_learning_progress(
    param_history,
    params.L_true,
    params.C_true,
    params.R_true,
    params.epochs,
)
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(
        fig, "parameter_learning", result_dir, "回路パラメータの学習による変化"
    )

# %%
t_sim = np.linspace(
    0,
    params.T * params.cycles_sim,
    params.cycles_sim * params.samples_per_cycle + 1,
)


dt_sim: np.ndarray = np.diff(t_sim)


# スイッチング信号
duty_phase = (t_sim[:-1] % params.T) / params.T
u_sim = (duty_phase < duty).astype(int)

# 入力電圧
vs_sim = np.ones(len(t_sim) - 1) * params.Vin
x_tensor = torch.tensor(np.c_[vs_sim, u_sim, dt_sim], dtype=torch.float32)

h_sim = [torch.zeros(1, 2)]

# シミュレーション実行
with torch.no_grad():
    for j in range(len(t_sim) - 1):
        h_current = buck_converter_cell(h_sim[-1], x_tensor[j : j + 1])
        h_sim.append(h_current)

h_sim_tensor = torch.cat(h_sim, dim=0)  # shape: (T+1, 2) みたいになる
iL_sim = h_sim_tensor[:, 0]
vC_sim = h_sim_tensor[:, 1]

# グラフ表示
fig, ax = plot_compare_tail(
    t_buck,
    iL_buck,
    vC_buck,
    "Measured",
    t_sim,
    iL_sim,
    vC_sim,
    "Predicted",
    T=params.T,
    title="Simulation Result",
    style2="scatter",
    N_cycles=10000,
)


if keep_log:
    save_figure_to_log(
        fig,
        "all_prediction",
        result_dir,
        f"シミュレーション結果(0から{params.cycles_sim}周期までシミュレーションし、定常箇所と実機のデータの比較)",
    )

fig, ax = plot_compare_tail(
    t_buck,
    iL_buck,
    vC_buck,
    "Measured",
    t_sim,
    iL_sim,
    vC_sim,
    "Predicted",
    T=params.T,
    title="Simulation Result",
    style2="scatter",
)

# %%
fig_list = plot_iLvC(
    t_sim,
    iL_sim,
    vC_sim,
    T=params.T,
    title="Simulation Result",
    plot_style="scatter",
    show_tail=(50, 10, 1),
)

if keep_log:
    for i, (fig, _) in enumerate(fig_list):
        save_figure_to_log(
            fig,
            f"シミュレーション結果_{i}",
            result_dir,
            "シミュレーション結果" if i == 0 else None,
        )

# %% [markdown]
# # GRU

# %% [markdown]
# ## 前処理
#
# 1. 教師データ: (実機データのノイズクリッピング前の波形) - (学習済み BuckConverterCell のおよそ定常部分)
# 2. 入力データ: iL, vC, vs, u, dt
# 3. データシーケンスの作成
# 4. train, valid, test に分割

# %%
@dataclass(frozen=True)
class Scalers:
    """GRU入力のスケーリング設定。

    - 状態/入力は無次元化（物理基準）
    - ノイズのみ標準化（train統計）し、推論時に必ず逆変換する
    """

    # 無次元化の基準
    v_base: float  # [V]
    i_base: float  # [A]
    t_base: float  # [s]

    # ノイズ標準化（trainのみ）
    noise_mean: torch.Tensor  # (2,)
    noise_std: torch.Tensor  # (2,)

    def nondim_h(self, h: torch.Tensor) -> torch.Tensor:
        """h=[iL,vC] -> 無次元化"""
        iL = h[:, 0] / self.i_base
        vC = h[:, 1] / self.v_base
        return torch.stack([iL, vC], dim=1)

    def nondim_x(self, x: torch.Tensor) -> torch.Tensor:
        """x=[vs,u,dt] -> vs,dtを無次元化。uは0/1なのでそのまま。"""
        vs = x[:, 0] / self.v_base
        u = x[:, 1]
        dt = x[:, 2] / self.t_base
        return torch.stack([vs, u, dt], dim=1)

    def z_noise(self, noise: torch.Tensor) -> torch.Tensor:
        """noise=[iL_noise,vC_noise] -> 標準化"""
        return (noise - self.noise_mean) / self.noise_std

    def inv_z_noise(self, noise_z: torch.Tensor) -> torch.Tensor:
        """標準化ノイズ -> 元スケールへ復元"""
        return noise_z * self.noise_std + self.noise_mean


def fit_scalers_physics(
    *,
    noise_train: torch.Tensor,
    vin: float,
    r_load: float,
    t_base: float,
    eps: float = 1e-8,
) -> Scalers:
    """trainノイズから標準化統計を作り、物理基準の無次元化とセットで返す。"""
    v_base = float(vin)
    i_base = float(vin / r_load)

    noise_mean = noise_train.mean(dim=0)
    noise_std = noise_train.std(dim=0, unbiased=False).clamp_min(eps)

    return Scalers(
        v_base=v_base,
        i_base=i_base,
        t_base=float(t_base),
        noise_mean=noise_mean,
        noise_std=noise_std,
    )


def create_sequences(
    h_data: torch.Tensor,
    x_data: torch.Tensor,
    noise_data: torch.Tensor,
    seq_len: int,
) -> tuple[torch.Tensor, torch.Tensor]:
    """
    時系列データを作成
    入力: [iL, vC, vs, u, dt, iL_noise, vC_noise]
    出力: [iL_noise, vC_noise]
    """
    sequences: list[torch.Tensor] = []
    targets: list[torch.Tensor] = []

    for i in range(len(h_data) - seq_len):
        # 入力特徴量: [iL, vC, vs, u, dt] + 過去のノイズ [iL_noise, vC_noise]
        seq_input: list[torch.Tensor] = []
        for j in range(seq_len):
            idx = i + j
            # 状態と入力
            features = torch.cat(
                [
                    h_data[idx],  # [iL, vC]
                    x_data[idx],  # [vs, u, dt]
                ]
            )
            # 過去のノイズ（存在する場合）
            if idx > 0:
                noise_features = noise_data[idx - 1]  # [iL_noise, vC_noise]
            else:
                # device/dtype を揃える
                noise_features = noise_data.new_zeros((2,))
            # 結合: [iL, vC, vs, u, dt, iL_noise, vC_noise] = 7次元
            combined = torch.cat([features, noise_features])
            seq_input.append(combined)

        sequences.append(torch.stack(seq_input))
        targets.append(noise_data[i + seq_len])

    return torch.stack(sequences), torch.stack(targets)


# t_downsampled 部分を切り出す
h_sim_tensor = h_sim_tensor[-len(t_downsampled) :]
h_sim_tensor = h_sim_tensor[:-1]

iL_tensor = torch.tensor(iL_gru, dtype=torch.float32)
vC_tensor = torch.tensor(vC_gru, dtype=torch.float32)
h_meas_tensor = torch.stack([iL_tensor[:-1], vC_tensor[:-1]], dim=1)

n = min(h_meas_tensor.shape[0], h_sim_tensor.shape[0])
h_noise = h_meas_tensor[:n] - h_sim_tensor[:n]

# データセットを作成
iL_train = iL_tensor[: train_len + 1]
vC_train = vC_tensor[: train_len + 1]
h_train = torch.stack([iL_train[:-1], vC_train[:-1]], dim=1)

# --- スケーリング（無次元化 + ノイズ標準化） ---
noise_train_raw = h_noise[: len(h_train)]
scalers = fit_scalers_physics(
    noise_train=noise_train_raw,
    vin=float(params.Vin),
    r_load=float(params.R_true),
    t_base=float(params.T),
)

h_train_nd = scalers.nondim_h(h_train)
x_train_nd = scalers.nondim_x(x_train)
noise_train_z = scalers.z_noise(noise_train_raw)

X_train_seq, y_train_seq = create_sequences(
    h_train_nd,
    x_train_nd,
    noise_train_z,
    params.seq_length,
)

iL_valid = iL_tensor[train_len : train_len + valid_len + 1]
vC_valid = vC_tensor[train_len : train_len + valid_len + 1]
h_valid = torch.stack([iL_valid[:-1], vC_valid[:-1]], dim=1)

noise_valid_raw = h_noise[len(h_train) : len(h_train) + len(h_valid)]
h_valid_nd = scalers.nondim_h(h_valid)
x_valid_nd = scalers.nondim_x(x_valid)
noise_valid_z = scalers.z_noise(noise_valid_raw)

X_valid_seq, y_valid_seq = create_sequences(
    h_valid_nd,
    x_valid_nd,
    noise_valid_z,
    params.seq_length,
)


iL_test = iL_tensor[train_len + valid_len :]
vC_test = vC_tensor[train_len + valid_len :]
h_test = torch.stack([iL_test[:-1], vC_test[:-1]], dim=1)

noise_test_raw = h_noise[len(h_train) + len(h_valid) :]
h_test_nd = scalers.nondim_h(h_test)
x_test_nd = scalers.nondim_x(x_test)
noise_test_z = scalers.z_noise(noise_test_raw)

X_test_seq, y_test_seq = create_sequences(
    h_test_nd,
    x_test_nd,
    noise_test_z,
    params.seq_length,
)

# 可視化/評価用のraw教師（create_sequencesの仕様より）
seq_len_int = int(params.seq_length)
y_train_seq_raw = noise_train_raw[seq_len_int:]
y_valid_seq_raw = noise_valid_raw[seq_len_int:]
y_test_seq_raw = noise_test_raw[seq_len_int:]

print(f"学習データ: {X_train_seq.shape} -> {y_train_seq.shape}")
print(f"検証データ: {X_valid_seq.shape} -> {y_valid_seq.shape}")
print(f"テストデータ: {X_test_seq.shape} -> {y_test_seq.shape}")
print(
    f"入力特徴量の次元: {X_train_seq.shape[2]} (iL, vC, vs, u, dt, iL_noise, vC_noise)"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 107
#     103     return torch.stack(sequences), torch.stack(targets)
#     106 # t_downsampled 部分を切り出す
# --> 107 h_sim_tensor = h_sim_tensor[-len(t_downsampled) :]
#     108 h_sim_tensor = h_sim_tensor[:-1]
#     110 iL_tensor = torch.tensor(iL_gru, dtype=torch.float32)
#
# NameError: name 't_downsampled' is not defined

# %%
# 学習データ
X_train_seq_np: np.ndarray = X_train_seq.detach().cpu().numpy()
y_train_seq_np: np.ndarray = y_train_seq.detach().cpu().numpy()

# 入力特徴量名と単位（無次元化/標準化後）
feature_names: list[str] = [
    "iL_nd",
    "vC_nd",
    "vs_nd",
    "u",
    "dt_nd",
    "iL_noise_z",
    "vC_noise_z",
]
feature_units: list[str] = ["[-]", "[-]", "[-]", "[-]", "[-]", "[-]", "[-]"]


fig, axs = plt.subplots(7, 1, figsize=(14, 12), sharex=True)

last_timestep_features: np.ndarray = X_train_seq_np[:, -1, :]  # [N, 7]

# time_axisをt_train（μs単位）に
time_axis: np.ndarray = t_train[: X_train_seq_np.shape[0]] * 1e6  # μs

for i in range(7):
    axs[i].plot(time_axis, last_timestep_features[:, i], linewidth=1.5, alpha=0.7)
    axs[i].set_ylabel(f"{feature_names[i]} {feature_units[i]}", fontsize=11)
    axs[i].grid(True, alpha=0.3)
    axs[i].set_title(
        f"GRU Training Data: {feature_names[i]} (Value at Last Time Step)",
        fontsize=12,
        fontweight="bold",
    )

axs[6].set_xlabel("Time [μs]", fontsize=12)
plt.tight_layout()
plt.show()

if keep_log:
    save_figure_to_log(
        fig,
        "gru_training_data_features",
        result_dir,
        "GRU 学習データ",
    )

# %% [markdown]
# ## 学習

# %%
# 学習
gru_model = GRUModel(
    input_size=X_train_seq.shape[2],
    hidden_size=32,
    num_layers=2,
    output_size=2,
    seq_length=params.seq_length,
)


gru_optimizer = optim.Adam(gru_model.parameters(), lr=params.gru_lr)
gru_loss_fn = nn.MSELoss()

gru_loss_history = {"train": [], "valid": []}

for epoch in range(params.gru_epochs):
    # 学習モード
    gru_model.train()
    gru_optimizer.zero_grad()
    noise_pred_train = gru_model(X_train_seq)
    train_loss = gru_loss_fn(noise_pred_train, y_train_seq)
    train_loss.backward()
    gru_optimizer.step()

    gru_loss_history["train"].append(train_loss.item())

    # 検証モード
    gru_model.eval()
    with torch.no_grad():
        noise_pred_valid = gru_model(X_valid_seq)
        valid_loss = gru_loss_fn(noise_pred_valid, y_valid_seq)
        gru_loss_history["valid"].append(valid_loss.item())

    if (epoch + 1) % 50 == 0:
        print(
            f"Epoch {epoch + 1}/{params.gru_epochs}: "
            f"Train Loss={train_loss.item():.6e}, "
            f"Valid Loss={valid_loss.item():.6e}"
        )

gru_model.eval()
with torch.no_grad():
    noise_pred_test = gru_model(X_test_seq)
    test_loss = gru_loss_fn(noise_pred_test, y_test_seq)
    print(f"Test Loss={test_loss.item():.6e}")

# %% [markdown]
# ## 結果確認

# %%
# Lossの遷移をグラフ表示
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

epochs_list = range(1, params.gru_epochs + 1)
ax.plot(
    epochs_list, gru_loss_history["train"], label="Train Loss", linewidth=2, alpha=0.8
)
ax.plot(
    epochs_list, gru_loss_history["valid"], label="Valid Loss", linewidth=2, alpha=0.8
)

ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss (MSE)", fontsize=12)
ax.set_title("Loss Transition", fontsize=14, fontweight="bold")
ax.set_yscale("log")
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(fig, "gru_loss_transition", result_dir, "GRU Lossの遷移")

# %%
# GRUでノイズを予測（テスト）
gru_model.eval()
with torch.no_grad():
    noise_pred_test = gru_model(X_test_seq)


noise_pred_test_cpu = noise_pred_test.detach().cpu()
noise_true_test_cpu = y_test_seq.detach().cpu()

# plot_compare_tail を使って比較（末尾N周期）
seq_len = int(params.seq_length)

t_noise = np.asarray(t_test[:-1])[seq_len:]
min_len = min(
    t_noise.shape[0],
    int(noise_true_test_cpu.shape[0]),
    int(noise_pred_test_cpu.shape[0]),
)

t_noise = t_noise[:min_len]
true_noise_z = noise_true_test_cpu[:min_len].numpy()
pred_noise_z = noise_pred_test_cpu[:min_len].numpy()

# 標準化ノイズ -> rawノイズへ復元（推論時に必ず戻す）
true_noise_raw = y_test_seq_raw[:min_len].detach().cpu().numpy()
pred_noise_raw = scalers.inv_z_noise(noise_pred_test_cpu[:min_len]).numpy()

fig1, _ = plot_compare_tail(
    t1=t_noise,
    iL1=true_noise_raw[:, 0],
    vC1=true_noise_raw[:, 1],
    label1="true noise (raw)",
    t2=t_noise,
    iL2=pred_noise_raw[:, 0],
    vC2=pred_noise_raw[:, 1],
    label2="pred noise (GRU, raw)",
    T=float(params.T),
    N_cycles=4,
    title="GRU noise prediction (test)",
)


if keep_log:
    save_figure_to_log(
        fig1,
        "gru_noise_pred_test",
        result_dir,
        "GRU noise予測(テスト)",
    )

# %% [markdown]
# # BuckConverterCell + GRU の結果

# %%
# プロット
N_cycles: int = 4
T: float = float(params.T)
seq_len: int = int(params.seq_length)

# --- BuckConverterCell: 実機時間(t_downsampled)に対応する末尾部分を抽出 ---
n_meas: int = int(len(t_downsampled))
t_sim_meas_raw: np.ndarray = np.asarray(t_sim[-n_meas:], dtype=float)

iL_sim_meas: np.ndarray = np.asarray(
    iL_sim[-n_meas:].detach().cpu().numpy(), dtype=float
)
vC_sim_meas: np.ndarray = np.asarray(
    vC_sim[-n_meas:].detach().cpu().numpy(), dtype=float
)

# t_sim末尾は (t_downsampled + offset) なので、offset を引いて合わせる
offset: float = float(t_sim_meas_raw[0] - float(t_downsampled[0]))
t_sim_meas: np.ndarray = t_sim_meas_raw - offset  # ≒ t_downsampled

# --- test区間をBuck側の時間で切り出す ---
t_test_np: np.ndarray = np.asarray(t_test, dtype=float)
start_idx: int = int(np.argmin(np.abs(t_sim_meas - float(t_test_np[0]))))
end_idx: int = min(start_idx + int(t_test_np.shape[0]), int(t_sim_meas.shape[0]))

t_test_used: np.ndarray = t_sim_meas[start_idx:end_idx]
iL_sim_test: np.ndarray = iL_sim_meas[start_idx:end_idx]
vC_sim_test: np.ndarray = vC_sim_meas[start_idx:end_idx]

# --- Measured(test) を同じ長さだけ取り出す ---
start_test_idx: int = int(train_len + valid_len)  # t_testと同じ開始位置

iL_meas_test: np.ndarray = np.asarray(
    iL_gru[start_test_idx : start_test_idx + int(t_test_used.shape[0])], dtype=float
)
vC_meas_test: np.ndarray = np.asarray(
    vC_gru[start_test_idx : start_test_idx + int(t_test_used.shape[0])], dtype=float
)

# --- GRU出力(pred_noise)は t_test[:-1][seq_len:] に対応 ---
t_noise_local: np.ndarray = np.asarray(t_test_used[:-1], dtype=float)[seq_len:]
# pred_noise_raw はセル24で「標準化->raw復元」済み
pred_noise_np: np.ndarray = np.asarray(pred_noise_raw, dtype=float)

min_len2: int = int(
    min(
        t_noise_local.shape[0],
        pred_noise_np.shape[0],
        iL_sim_test.shape[0] - 1 - seq_len,
        vC_sim_test.shape[0] - 1 - seq_len,
        iL_meas_test.shape[0] - 1 - seq_len,
        vC_meas_test.shape[0] - 1 - seq_len,
    )
)

if min_len2 <= 0:
    raise ValueError(
        "長さが合わず、描画できません。"
        " t_test/t_sim/pred_noise/seq_length の整合を確認してください。"
    )

# すべて同じ長さに揃える
# t は [s]
t_view: np.ndarray = t_noise_local[:min_len2]

iL_meas: np.ndarray = np.asarray(iL_meas_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]
vC_meas: np.ndarray = np.asarray(vC_meas_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]

iL_buck: np.ndarray = np.asarray(iL_sim_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]
vC_buck: np.ndarray = np.asarray(vC_sim_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]

iL_gru: np.ndarray = pred_noise_np[:min_len2, 0]
vC_gru: np.ndarray = pred_noise_np[:min_len2, 1]

fig_iL, _, fig_vC, _ = plot_buck_gru_components_tail(
    t=t_view,
    iL_meas=iL_meas,
    vC_meas=vC_meas,
    iL_buck=iL_buck,
    vC_buck=vC_buck,
    iL_gru=iL_gru,
    vC_gru=vC_gru,
    T=T,
    N_cycles=float(N_cycles),
    title="note4 (test)",
    include_overlay=True,
)
plt.show()

if keep_log:
    save_figure_to_log(
        fig_iL,
        "tail4T_iL_meas_buck_gru_sum",
        result_dir,
        "iL: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )
    save_figure_to_log(
        fig_vC,
        "tail4T_vC_meas_buck_gru_sum",
        result_dir,
        "vC: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )
