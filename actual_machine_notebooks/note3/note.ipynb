# %% [markdown]
# # やること

# %%
from dataclasses import asdict, dataclass

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn, optim

from src.utils.load_data import load_data, path_list
from src.utils.models import BuckConverterCell, GRUModel
from src.utils.plot_data import (
    plot_buck_gru_components_tail,
    plot_compare_tail,
    plot_iLvC,
    plot_param_learning_progress,
    plot_u_vs_iL_vC,
)
from src.utils.save_log import (
    create_result_dir,
    init_log,
    save_figure_to_log,
)

# 乱数固定用の処理
seed = 10
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)

# %%
keep_log: bool = False


@dataclass(frozen=True)
class Params:
    data_path: str = path_list.path3

    # 真値パラメータ
    L_true: float = 223.6e-6
    C_true: float = 73.8e-6
    R_true: float = 5
    L_init = 200e-6
    C_init = 100e-6
    R_init = 8.0

    Vin: int = 10
    Vref: int = 5
    duty: float = Vref / Vin
    f_sw: float = 1e5  # スイッチング周波数
    T: float = 1 / f_sw  # 1周期の実時間
    cycles: int = 10
    samples_per_cycle: int = 200

    train_ratio = 0.3
    valid_ratio = 0.3
    # test_ratio = 1 - train_ratio - valid_ratio

    clipped_k: float = 2.0

    # 学習パラメータ

    # 異なるパラメータに異なる学習率を設定
    lr_l = 5e-2
    lr_c = 1e-2
    lr_r = 2e-2

    epochs = 50000

    # GRU学習用のデータ準備（時系列データ）
    seq_length = 10

    gru_lr = 0.001
    gru_epochs = 200


params = Params()

# %%
# ログ保存の初期化
if keep_log:
    result_dir = create_result_dir(
        "note3",
        base_dir="results/actual",
        config_dict=asdict(params),
    )
    log_path = init_log(result_dir, "actual_machine_notebooks/note3/note.ipynb")

# %% [markdown]
# # BuckConverterCell

# %% [markdown]
# ## 前処理
#
# 1. 実機データの読み込み
# 2. ダウンサンプリング
# 3. ノイズのクリッピング
# 4. train, valid, test に分割

# %%
# 実機データの読み込み
# t_raw, iL_raw, vC_raw = load_data(
#     path=params.data_path,
#     downsample_step=1,  # ダウンスケールしない
#     T=params.T,
#     cycles=params.cycles,
#     iL_label="CH2",
#     vC_label="CH1",
# )
# シミュレーションデータ
t_raw, iL_raw, vC_raw = load_data(
    path="../../data/buck_sim_Vin10.0_Vref5.0_fs100000.0_ppc200_cyc1000/buck_sim_Vin10.0_Vref5.0_fs100000.csv",
    skiprows=0,
    downsample_step=1,  # ダウンスケールしない
    T=params.T,
    cycles=params.cycles,
    time_label="t",
    iL_label="iL",
    vC_label="vC",
)

# ダウンサンプリング
downsample_step = len(t_raw) // (params.samples_per_cycle * params.cycles)
t_downsampled: np.ndarray = t_raw[::downsample_step]
iL_downsampled: np.ndarray = iL_raw[::downsample_step]
vC_downsampled: np.ndarray = vC_raw[::downsample_step]


print(f"{len(t_downsampled)=}")
print(f"{len(iL_downsampled)=}")
print(f"{len(vC_downsampled)=}")


# ノイズのクリッピング
def clip_by_mean_std(x: np.ndarray, k: float) -> tuple[np.ndarray, float, float]:
    mu = float(np.mean(x))
    std = float(np.std(x))
    lo = mu - k * std
    hi = mu + k * std
    x_clipped = np.clip(x, lo, hi)
    return x_clipped.astype(x.dtype, copy=False), lo, hi


iL_clipped, iL_lo, iL_hi = clip_by_mean_std(iL_downsampled, k=params.clipped_k)
vC_clipped, vC_lo, vC_hi = clip_by_mean_std(vC_downsampled, k=params.clipped_k)

# プロット
fig, ax = plot_compare_tail(
    t_downsampled,
    iL_downsampled,
    vC_downsampled,
    "before clip",
    t_downsampled,
    iL_clipped,
    vC_clipped,
    "after clip",
    params.T,
    title="Comparison before and after clipping",
    iL_range=(iL_lo, iL_hi),
    vC_range=(vC_lo, vC_hi),
)
if keep_log:
    save_figure_to_log(fig, "compare_tail.png", result_dir)
# Out:
# len(t_downsampled)=2001
# len(iL_downsampled)=2001
# len(vC_downsampled)=2001

# %%
# スイッチング信号
duty_phase = (t_downsampled[:-1] % params.T) / params.T
u = (duty_phase < params.duty).astype(int)

# 入力電圧
vs = np.ones(len(t_downsampled) - 1) * params.Vin

fig, ax = plot_u_vs_iL_vC(
    t_downsampled,
    u,
    vs,
    iL_clipped,
    vC_clipped,
    params.T,
)

if keep_log:
    save_figure_to_log(fig, "u_vs_iL_vC.png", result_dir)

# %%
# train, valid, test の分割
dt = t_downsampled[1:] - t_downsampled[:-1]

# numpy配列をテンソルに変換
dt_tensor = torch.tensor(dt, dtype=torch.float32)
u_tensor = torch.tensor(u, dtype=torch.float32)
vs_tensor = torch.tensor(vs, dtype=torch.float32)
iL_clipped_tensor = torch.tensor(iL_clipped, dtype=torch.float32)
vC_clipped_tensor = torch.tensor(vC_clipped, dtype=torch.float32)

# train
train_len = int(len(dt) * params.train_ratio)

t_train = t_downsampled[: train_len + 1]
dt_train = dt_tensor[:train_len]
u_train = u_tensor[:train_len]
vs_train = vs_tensor[:train_len]
iL_clipped_train = iL_clipped_tensor[: train_len + 1]
vC_clipped_train = vC_clipped_tensor[: train_len + 1]

h_clipped_train = torch.stack(
    [iL_clipped_train[:-1], vC_clipped_train[:-1]],
    dim=1,
)
x_train = torch.stack([vs_train, u_train, dt_train], dim=1)
target_clipped_train = torch.stack(
    [iL_clipped_train[1:], vC_clipped_train[1:]],
    dim=1,
)


# valid
valid_len = int(len(dt) * params.valid_ratio)

t_valid = t_downsampled[train_len : train_len + valid_len]
dt_valid = dt_tensor[train_len : train_len + valid_len]
u_valid = u_tensor[train_len : train_len + valid_len]
vs_valid = vs_tensor[train_len : train_len + valid_len]
iL_clipped_valid = iL_clipped_tensor[train_len : train_len + valid_len + 1]
vC_clipped_valid = vC_clipped_tensor[train_len : train_len + valid_len + 1]

h_clipped_valid = torch.stack(
    [iL_clipped_valid[:-1], vC_clipped_valid[:-1]],
    dim=1,
)
x_valid = torch.stack([vs_valid, u_valid, dt_valid], dim=1)
target_clipped_valid = torch.stack(
    [iL_clipped_valid[1:], vC_clipped_valid[1:]],
    dim=1,
)

# test
t_test = t_downsampled[train_len + valid_len :]
dt_test = dt_tensor[train_len + valid_len :]
u_test = u_tensor[train_len + valid_len :]
vs_test = vs_tensor[train_len + valid_len :]
iL_clipped_test = iL_clipped_tensor[train_len + valid_len :]
vC_clipped_test = vC_clipped_tensor[train_len + valid_len :]

h_clipped_test = torch.stack(
    [iL_clipped_test[:-1], vC_clipped_test[:-1]],
    dim=1,
)
x_test = torch.stack([vs_test, u_test, dt_test], dim=1)
target_clipped_test = torch.stack(
    [iL_clipped_test[1:], vC_clipped_test[1:]],
    dim=1,
)

print(f"{h_clipped_train.shape=}")
print(f"{x_train.shape=}")
print(f"{target_clipped_train.shape=}")

print(f"{h_clipped_valid.shape=}")
print(f"{x_valid.shape=}")
print(f"{target_clipped_valid.shape=}")

print(f"{h_clipped_test.shape=}")
print(f"{x_test.shape=}")
print(f"{target_clipped_test.shape=}")
# Out:
# h_clipped_train.shape=torch.Size([600, 2])
# x_train.shape=torch.Size([600, 3])
# target_clipped_train.shape=torch.Size([600, 2])
# h_clipped_valid.shape=torch.Size([600, 2])
# x_valid.shape=torch.Size([600, 3])
# target_clipped_valid.shape=torch.Size([600, 2])
# h_clipped_test.shape=torch.Size([800, 2])
# x_test.shape=torch.Size([800, 3])
# target_clipped_test.shape=torch.Size([800, 2])

# %% [markdown]
# ## 学習

# %%
buck_converter_cell = BuckConverterCell(
    L_init=params.L_init,
    C_init=params.C_init,
    R_init=params.R_init,
)

optimizer = optim.Adam(
    [
        {"params": [buck_converter_cell.log_L], "lr": params.lr_l},
        {"params": [buck_converter_cell.log_C], "lr": params.lr_c},
        {"params": [buck_converter_cell.log_R], "lr": params.lr_r},
    ]
)

loss_fn = nn.MSELoss()

# 損失履歴を保存
loss_history = {"train": [], "valid": []}
param_history = {"L": [], "C": [], "R": []}

# 学習ループ
for epoch in range(params.epochs):
    # 学習モード
    buck_converter_cell.train()
    optimizer.zero_grad()
    h_pred_train = buck_converter_cell(h_clipped_train, x_train)
    train_loss = loss_fn(h_pred_train, target_clipped_train)
    train_loss.backward()
    optimizer.step()

    loss_history["train"].append(train_loss.item())

    # 検証モード（勾配計算なし）
    buck_converter_cell.eval()
    with torch.no_grad():
        h_pred_valid = buck_converter_cell(h_clipped_valid, x_valid)
        valid_loss = loss_fn(h_pred_valid, target_clipped_valid)
        loss_history["valid"].append(valid_loss.item())

    # パラメータの履歴を保存
    param_history["L"].append(buck_converter_cell.log_L.exp().item())
    param_history["C"].append(buck_converter_cell.log_C.exp().item())
    param_history["R"].append(buck_converter_cell.log_R.exp().item())

    if epoch % 50 == 0:
        output_line = (
            f"Epoch {epoch}: Train Loss={train_loss.item():.6e}, "
            f"Valid Loss={valid_loss.item():.6e}\n"
            f"  L={buck_converter_cell.log_L.exp().item() * 1e6:.1f}µH "
            f"(true={params.L_true * 1e6:.1f})"
            f"C={buck_converter_cell.log_C.exp().item() * 1e6:.1f}µF "
            f"(true={params.C_true * 1e6:.1f})"
            f"R={buck_converter_cell.log_R.exp().item():.2f}Ω "
            f"(true={params.R_true:.1f})"
        )
        print(output_line)

# テストデータでの評価
buck_converter_cell.eval()
with torch.no_grad():
    h_pred_test = buck_converter_cell(h_clipped_test, x_test)
    test_loss = loss_fn(h_pred_test, target_clipped_test)

print(f"Final test loss: {test_loss.item():.6e}")
# Out:
# Epoch 0: Train Loss=2.640274e-07, Valid Loss=2.498338e-07
#   L=210.0µH (true=223.6)C=100.8µF (true=73.8)R=7.86Ω (true=5.0)
# Epoch 50: Train Loss=1.948507e-07, Valid Loss=1.982342e-07
#   L=274.5µH (true=223.6)C=118.3µF (true=73.8)R=4.85Ω (true=5.0)
# Epoch 100: Train Loss=1.945828e-07, Valid Loss=1.980588e-07
#   L=269.6µH (true=223.6)C=118.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 150: Train Loss=1.945833e-07, Valid Loss=1.980639e-07
#   L=269.4µH (true=223.6)C=118.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 200: Train Loss=1.945811e-07, Valid Loss=1.980592e-07
#   L=269.4µH (true=223.6)C=117.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 250: Train Loss=1.945796e-07, Valid Loss=1.980578e-07
#   L=269.4µH (true=223.6)C=117.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 300: Train Loss=1.945789e-07, Valid Loss=1.980571e-07
#   L=269.4µH (true=223.6)C=116.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 350: Train Loss=1.945780e-07, Valid Loss=1.980562e-07
#   L=269.4µH (true=223.6)C=116.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 400: Train Loss=1.945776e-07, Valid Loss=1.980559e-07
#   L=269.4µH (true=223.6)C=115.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 450: Train Loss=1.945774e-07, Valid Loss=1.980557e-07
#   L=269.4µH (true=223.6)C=115.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 500: Train Loss=1.945773e-07, Valid Loss=1.980555e-07
#   L=269.4µH (true=223.6)C=114.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 550: Train Loss=1.945768e-07, Valid Loss=1.980550e-07
#   L=269.4µH (true=223.6)C=114.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 600: Train Loss=1.945759e-07, Valid Loss=1.980541e-07
#   L=269.4µH (true=223.6)C=113.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 650: Train Loss=1.945754e-07, Valid Loss=1.980536e-07
#   L=269.4µH (true=223.6)C=113.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 700: Train Loss=1.945751e-07, Valid Loss=1.980533e-07
#   L=269.4µH (true=223.6)C=113.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 750: Train Loss=1.945748e-07, Valid Loss=1.980531e-07
#   L=269.4µH (true=223.6)C=112.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 800: Train Loss=1.945743e-07, Valid Loss=1.980525e-07
#   L=269.4µH (true=223.6)C=112.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 850: Train Loss=1.945736e-07, Valid Loss=1.980519e-07
#   L=269.4µH (true=223.6)C=111.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 900: Train Loss=1.945732e-07, Valid Loss=1.980515e-07
#   L=269.4µH (true=223.6)C=111.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 950: Train Loss=1.945729e-07, Valid Loss=1.980511e-07
#   L=269.4µH (true=223.6)C=110.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1000: Train Loss=1.945725e-07, Valid Loss=1.980507e-07
#   L=269.4µH (true=223.6)C=110.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1050: Train Loss=1.945719e-07, Valid Loss=1.980501e-07
#   L=269.4µH (true=223.6)C=109.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1100: Train Loss=1.945714e-07, Valid Loss=1.980496e-07
#   L=269.4µH (true=223.6)C=109.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1150: Train Loss=1.945710e-07, Valid Loss=1.980492e-07
#   L=269.4µH (true=223.6)C=108.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1200: Train Loss=1.945706e-07, Valid Loss=1.980488e-07
#   L=269.4µH (true=223.6)C=108.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1250: Train Loss=1.945700e-07, Valid Loss=1.980483e-07
#   L=269.4µH (true=223.6)C=107.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1300: Train Loss=1.945695e-07, Valid Loss=1.980478e-07
#   L=269.4µH (true=223.6)C=107.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1350: Train Loss=1.945692e-07, Valid Loss=1.980474e-07
#   L=269.4µH (true=223.6)C=106.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1400: Train Loss=1.945688e-07, Valid Loss=1.980471e-07
#   L=269.4µH (true=223.6)C=106.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1450: Train Loss=1.945683e-07, Valid Loss=1.980466e-07
#   L=269.4µH (true=223.6)C=105.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1500: Train Loss=1.945678e-07, Valid Loss=1.980461e-07
#   L=269.4µH (true=223.6)C=105.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1550: Train Loss=1.945674e-07, Valid Loss=1.980456e-07
#   L=269.4µH (true=223.6)C=104.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1600: Train Loss=1.945670e-07, Valid Loss=1.980453e-07
#   L=269.4µH (true=223.6)C=104.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1650: Train Loss=1.945666e-07, Valid Loss=1.980448e-07
#   L=269.4µH (true=223.6)C=104.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1700: Train Loss=1.945661e-07, Valid Loss=1.980443e-07
#   L=269.4µH (true=223.6)C=103.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1750: Train Loss=1.945657e-07, Valid Loss=1.980439e-07
#   L=269.4µH (true=223.6)C=103.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1800: Train Loss=1.945653e-07, Valid Loss=1.980436e-07
#   L=269.4µH (true=223.6)C=102.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1850: Train Loss=1.945649e-07, Valid Loss=1.980431e-07
#   L=269.4µH (true=223.6)C=102.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1900: Train Loss=1.945644e-07, Valid Loss=1.980427e-07
#   L=269.4µH (true=223.6)C=101.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 1950: Train Loss=1.945641e-07, Valid Loss=1.980423e-07
#   L=269.4µH (true=223.6)C=101.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2000: Train Loss=1.945636e-07, Valid Loss=1.980419e-07
#   L=269.4µH (true=223.6)C=100.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2050: Train Loss=1.945633e-07, Valid Loss=1.980415e-07
#   L=269.4µH (true=223.6)C=100.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2100: Train Loss=1.945628e-07, Valid Loss=1.980411e-07
#   L=269.4µH (true=223.6)C=100.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2150: Train Loss=1.945625e-07, Valid Loss=1.980407e-07
#   L=269.4µH (true=223.6)C=99.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2200: Train Loss=1.945621e-07, Valid Loss=1.980404e-07
#   L=269.4µH (true=223.6)C=99.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2250: Train Loss=1.945618e-07, Valid Loss=1.980400e-07
#   L=269.4µH (true=223.6)C=98.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2300: Train Loss=1.945614e-07, Valid Loss=1.980396e-07
#   L=269.4µH (true=223.6)C=98.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2350: Train Loss=1.945610e-07, Valid Loss=1.980392e-07
#   L=269.4µH (true=223.6)C=98.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2400: Train Loss=1.945606e-07, Valid Loss=1.980389e-07
#   L=269.4µH (true=223.6)C=97.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2450: Train Loss=1.945603e-07, Valid Loss=1.980385e-07
#   L=269.4µH (true=223.6)C=97.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2500: Train Loss=1.945599e-07, Valid Loss=1.980381e-07
#   L=269.4µH (true=223.6)C=96.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2550: Train Loss=1.945596e-07, Valid Loss=1.980378e-07
#   L=269.4µH (true=223.6)C=96.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2600: Train Loss=1.945593e-07, Valid Loss=1.980375e-07
#   L=269.4µH (true=223.6)C=96.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2650: Train Loss=1.945589e-07, Valid Loss=1.980372e-07
#   L=269.4µH (true=223.6)C=95.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2700: Train Loss=1.945586e-07, Valid Loss=1.980368e-07
#   L=269.4µH (true=223.6)C=95.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2750: Train Loss=1.945582e-07, Valid Loss=1.980365e-07
#   L=269.4µH (true=223.6)C=95.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2800: Train Loss=1.945579e-07, Valid Loss=1.980361e-07
#   L=269.4µH (true=223.6)C=94.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2850: Train Loss=1.945577e-07, Valid Loss=1.980359e-07
#   L=269.4µH (true=223.6)C=94.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2900: Train Loss=1.945573e-07, Valid Loss=1.980356e-07
#   L=269.4µH (true=223.6)C=93.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 2950: Train Loss=1.945570e-07, Valid Loss=1.980353e-07
#   L=269.4µH (true=223.6)C=93.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3000: Train Loss=1.945567e-07, Valid Loss=1.980350e-07
#   L=269.4µH (true=223.6)C=93.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3050: Train Loss=1.945564e-07, Valid Loss=1.980347e-07
#   L=269.4µH (true=223.6)C=92.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3100: Train Loss=1.945562e-07, Valid Loss=1.980344e-07
#   L=269.4µH (true=223.6)C=92.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3150: Train Loss=1.945558e-07, Valid Loss=1.980341e-07
#   L=269.4µH (true=223.6)C=92.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3200: Train Loss=1.945556e-07, Valid Loss=1.980338e-07
#   L=269.4µH (true=223.6)C=91.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3250: Train Loss=1.945553e-07, Valid Loss=1.980336e-07
#   L=269.4µH (true=223.6)C=91.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3300: Train Loss=1.945551e-07, Valid Loss=1.980333e-07
#   L=269.4µH (true=223.6)C=91.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3350: Train Loss=1.945548e-07, Valid Loss=1.980331e-07
#   L=269.4µH (true=223.6)C=90.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3400: Train Loss=1.945546e-07, Valid Loss=1.980328e-07
#   L=269.4µH (true=223.6)C=90.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3450: Train Loss=1.945543e-07, Valid Loss=1.980326e-07
#   L=269.4µH (true=223.6)C=90.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3500: Train Loss=1.945541e-07, Valid Loss=1.980323e-07
#   L=269.4µH (true=223.6)C=89.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3550: Train Loss=1.945539e-07, Valid Loss=1.980321e-07
#   L=269.4µH (true=223.6)C=89.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3600: Train Loss=1.945536e-07, Valid Loss=1.980319e-07
#   L=269.4µH (true=223.6)C=89.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3650: Train Loss=1.945533e-07, Valid Loss=1.980316e-07
#   L=269.4µH (true=223.6)C=89.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3700: Train Loss=1.945532e-07, Valid Loss=1.980315e-07
#   L=269.4µH (true=223.6)C=88.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3750: Train Loss=1.945530e-07, Valid Loss=1.980313e-07
#   L=269.4µH (true=223.6)C=88.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3800: Train Loss=1.945527e-07, Valid Loss=1.980310e-07
#   L=269.4µH (true=223.6)C=88.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3850: Train Loss=1.945526e-07, Valid Loss=1.980308e-07
#   L=269.4µH (true=223.6)C=87.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3900: Train Loss=1.945524e-07, Valid Loss=1.980306e-07
#   L=269.4µH (true=223.6)C=87.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 3950: Train Loss=1.945522e-07, Valid Loss=1.980304e-07
#   L=269.4µH (true=223.6)C=87.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4000: Train Loss=1.945520e-07, Valid Loss=1.980302e-07
#   L=269.4µH (true=223.6)C=87.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4050: Train Loss=1.945518e-07, Valid Loss=1.980301e-07
#   L=269.4µH (true=223.6)C=86.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4100: Train Loss=1.945516e-07, Valid Loss=1.980299e-07
#   L=269.4µH (true=223.6)C=86.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4150: Train Loss=1.945515e-07, Valid Loss=1.980297e-07
#   L=269.4µH (true=223.6)C=86.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4200: Train Loss=1.945513e-07, Valid Loss=1.980296e-07
#   L=269.4µH (true=223.6)C=86.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4250: Train Loss=1.945511e-07, Valid Loss=1.980294e-07
#   L=269.4µH (true=223.6)C=85.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4300: Train Loss=1.945510e-07, Valid Loss=1.980292e-07
#   L=269.4µH (true=223.6)C=85.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4350: Train Loss=1.945508e-07, Valid Loss=1.980291e-07
#   L=269.4µH (true=223.6)C=85.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4400: Train Loss=1.945507e-07, Valid Loss=1.980289e-07
#   L=269.4µH (true=223.6)C=85.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4450: Train Loss=1.945505e-07, Valid Loss=1.980288e-07
#   L=269.4µH (true=223.6)C=85.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4500: Train Loss=1.945504e-07, Valid Loss=1.980286e-07
#   L=269.4µH (true=223.6)C=84.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4550: Train Loss=1.945502e-07, Valid Loss=1.980285e-07
#   L=269.4µH (true=223.6)C=84.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4600: Train Loss=1.945501e-07, Valid Loss=1.980283e-07
#   L=269.4µH (true=223.6)C=84.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4650: Train Loss=1.945500e-07, Valid Loss=1.980282e-07
#   L=269.4µH (true=223.6)C=84.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4700: Train Loss=1.945498e-07, Valid Loss=1.980281e-07
#   L=269.4µH (true=223.6)C=83.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4750: Train Loss=1.945497e-07, Valid Loss=1.980280e-07
#   L=269.4µH (true=223.6)C=83.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4800: Train Loss=1.945496e-07, Valid Loss=1.980279e-07
#   L=269.4µH (true=223.6)C=83.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4850: Train Loss=1.945495e-07, Valid Loss=1.980277e-07
#   L=269.4µH (true=223.6)C=83.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4900: Train Loss=1.945494e-07, Valid Loss=1.980276e-07
#   L=269.4µH (true=223.6)C=83.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 4950: Train Loss=1.945493e-07, Valid Loss=1.980275e-07
#   L=269.4µH (true=223.6)C=82.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5000: Train Loss=1.945492e-07, Valid Loss=1.980274e-07
#   L=269.4µH (true=223.6)C=82.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5050: Train Loss=1.945491e-07, Valid Loss=1.980273e-07
#   L=269.4µH (true=223.6)C=82.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5100: Train Loss=1.945489e-07, Valid Loss=1.980272e-07
#   L=269.4µH (true=223.6)C=82.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5150: Train Loss=1.945489e-07, Valid Loss=1.980271e-07
#   L=269.4µH (true=223.6)C=82.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5200: Train Loss=1.945488e-07, Valid Loss=1.980271e-07
#   L=269.4µH (true=223.6)C=82.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5250: Train Loss=1.945487e-07, Valid Loss=1.980270e-07
#   L=269.4µH (true=223.6)C=81.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5300: Train Loss=1.945486e-07, Valid Loss=1.980269e-07
#   L=269.4µH (true=223.6)C=81.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5350: Train Loss=1.945485e-07, Valid Loss=1.980268e-07
#   L=269.4µH (true=223.6)C=81.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5400: Train Loss=1.945484e-07, Valid Loss=1.980267e-07
#   L=269.4µH (true=223.6)C=81.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5450: Train Loss=1.945484e-07, Valid Loss=1.980266e-07
#   L=269.4µH (true=223.6)C=81.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5500: Train Loss=1.945483e-07, Valid Loss=1.980266e-07
#   L=269.4µH (true=223.6)C=81.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5550: Train Loss=1.945482e-07, Valid Loss=1.980265e-07
#   L=269.4µH (true=223.6)C=80.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5600: Train Loss=1.945482e-07, Valid Loss=1.980264e-07
#   L=269.4µH (true=223.6)C=80.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5650: Train Loss=1.945481e-07, Valid Loss=1.980264e-07
#   L=269.4µH (true=223.6)C=80.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5700: Train Loss=1.945480e-07, Valid Loss=1.980263e-07
#   L=269.4µH (true=223.6)C=80.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5750: Train Loss=1.945479e-07, Valid Loss=1.980262e-07
#   L=269.4µH (true=223.6)C=80.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5800: Train Loss=1.945479e-07, Valid Loss=1.980261e-07
#   L=269.4µH (true=223.6)C=80.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5850: Train Loss=1.945478e-07, Valid Loss=1.980261e-07
#   L=269.4µH (true=223.6)C=80.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5900: Train Loss=1.945478e-07, Valid Loss=1.980260e-07
#   L=269.4µH (true=223.6)C=79.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 5950: Train Loss=1.945477e-07, Valid Loss=1.980260e-07
#   L=269.4µH (true=223.6)C=79.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6000: Train Loss=1.945477e-07, Valid Loss=1.980259e-07
#   L=269.4µH (true=223.6)C=79.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6050: Train Loss=1.945476e-07, Valid Loss=1.980259e-07
#   L=269.4µH (true=223.6)C=79.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6100: Train Loss=1.945476e-07, Valid Loss=1.980259e-07
#   L=269.4µH (true=223.6)C=79.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6150: Train Loss=1.945476e-07, Valid Loss=1.980258e-07
#   L=269.4µH (true=223.6)C=79.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6200: Train Loss=1.945474e-07, Valid Loss=1.980257e-07
#   L=269.4µH (true=223.6)C=79.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6250: Train Loss=1.945474e-07, Valid Loss=1.980257e-07
#   L=269.4µH (true=223.6)C=79.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6300: Train Loss=1.945474e-07, Valid Loss=1.980257e-07
#   L=269.4µH (true=223.6)C=78.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6350: Train Loss=1.945474e-07, Valid Loss=1.980256e-07
#   L=269.4µH (true=223.6)C=78.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6400: Train Loss=1.945473e-07, Valid Loss=1.980256e-07
#   L=269.4µH (true=223.6)C=78.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6450: Train Loss=1.945473e-07, Valid Loss=1.980255e-07
#   L=269.4µH (true=223.6)C=78.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6500: Train Loss=1.945472e-07, Valid Loss=1.980255e-07
#   L=269.4µH (true=223.6)C=78.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6550: Train Loss=1.945472e-07, Valid Loss=1.980255e-07
#   L=269.4µH (true=223.6)C=78.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6600: Train Loss=1.945472e-07, Valid Loss=1.980255e-07
#   L=269.4µH (true=223.6)C=78.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6650: Train Loss=1.945472e-07, Valid Loss=1.980254e-07
#   L=269.4µH (true=223.6)C=78.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6700: Train Loss=1.945471e-07, Valid Loss=1.980254e-07
#   L=269.4µH (true=223.6)C=78.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6750: Train Loss=1.945471e-07, Valid Loss=1.980253e-07
#   L=269.4µH (true=223.6)C=78.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6800: Train Loss=1.945471e-07, Valid Loss=1.980253e-07
#   L=269.4µH (true=223.6)C=77.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6850: Train Loss=1.945470e-07, Valid Loss=1.980253e-07
#   L=269.4µH (true=223.6)C=77.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6900: Train Loss=1.945470e-07, Valid Loss=1.980253e-07
#   L=269.4µH (true=223.6)C=77.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 6950: Train Loss=1.945470e-07, Valid Loss=1.980252e-07
#   L=269.4µH (true=223.6)C=77.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7000: Train Loss=1.945470e-07, Valid Loss=1.980252e-07
#   L=269.4µH (true=223.6)C=77.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7050: Train Loss=1.945469e-07, Valid Loss=1.980252e-07
#   L=269.4µH (true=223.6)C=77.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7100: Train Loss=1.945469e-07, Valid Loss=1.980252e-07
#   L=269.4µH (true=223.6)C=77.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7150: Train Loss=1.945469e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=77.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7200: Train Loss=1.945469e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=77.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7250: Train Loss=1.945468e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=77.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7300: Train Loss=1.945468e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=77.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7350: Train Loss=1.945468e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=77.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7400: Train Loss=1.945468e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=76.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7450: Train Loss=1.945468e-07, Valid Loss=1.980251e-07
#   L=269.4µH (true=223.6)C=76.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7500: Train Loss=1.945468e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7550: Train Loss=1.945468e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7600: Train Loss=1.945467e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7650: Train Loss=1.945467e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7700: Train Loss=1.945467e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7750: Train Loss=1.945467e-07, Valid Loss=1.980250e-07
#   L=269.4µH (true=223.6)C=76.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7800: Train Loss=1.945467e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7850: Train Loss=1.945467e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7900: Train Loss=1.945467e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 7950: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8000: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8050: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8100: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8150: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8200: Train Loss=1.945466e-07, Valid Loss=1.980249e-07
#   L=269.4µH (true=223.6)C=76.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8250: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8300: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8350: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8400: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8450: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8500: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8550: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8600: Train Loss=1.945466e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8650: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8700: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8750: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8800: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8850: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8900: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 8950: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9000: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9050: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9100: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9150: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9200: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9250: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9300: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9350: Train Loss=1.945465e-07, Valid Loss=1.980248e-07
#   L=269.4µH (true=223.6)C=75.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9400: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=75.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9450: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=75.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9500: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=75.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9550: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=75.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9600: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9650: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9700: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9750: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9800: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9850: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9900: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 9950: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10000: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.8µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10050: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10100: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10150: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10200: Train Loss=1.945465e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.7µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.6µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.5µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 10950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.4µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.3µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 11950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.2µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 12950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.1µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 13950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=74.0µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 14950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 15950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 16950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 17950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 18950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 19000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 19050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 19100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 19150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 19200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# ...
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 43950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 44950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 45950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 46950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 47950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 48950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49000: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49050: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49100: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49150: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49200: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49250: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49300: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49350: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49400: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49450: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49500: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49550: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49600: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49650: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49700: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49750: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49800: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49850: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49900: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Epoch 49950: Train Loss=1.945464e-07, Valid Loss=1.980247e-07
#   L=269.4µH (true=223.6)C=73.9µF (true=73.8)R=5.00Ω (true=5.0)
# Final test loss: 1.997133e-07

# %% [markdown]
# ## 結果確認

# %%
# Lossの遷移をグラフ表示
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

epochs_list = range(1, params.epochs + 1)
ax.plot(epochs_list, loss_history["train"], label="Train Loss", linewidth=2, alpha=0.8)
ax.plot(epochs_list, loss_history["valid"], label="Valid Loss", linewidth=2, alpha=0.8)

ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss (MSE)", fontsize=12)
ax.set_title("Loss Transition", fontsize=14, fontweight="bold")
ax.set_yscale("log")
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(fig, "loss_transition", result_dir, "Lossの遷移")

# %%
# 回路パラメータの学習による変化をグラフ表示
fig, ax = plot_param_learning_progress(
    param_history,
    params.L_true,
    params.C_true,
    params.R_true,
    params.epochs,
)
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(
        fig, "parameter_learning", result_dir, "回路パラメータの学習による変化"
    )

# %%
t_sim: np.ndarray = np.linspace(
    0,
    1000 * params.T,
    1000 * params.samples_per_cycle + 1,
)
t_additional = t_downsampled + t_sim[-1]
t_sim = np.concatenate([t_sim, t_additional])

dt_sim: np.ndarray = np.diff(t_sim)

# スイッチング信号
duty_phase = (t_sim[:-1] % params.T) / params.T
u_sim = (duty_phase < params.duty).astype(int)

# 入力電圧
vs_sim = np.ones(len(t_sim) - 1) * params.Vin
x_tensor = torch.tensor(np.c_[vs_sim, u_sim, dt_sim], dtype=torch.float32)

h_sim = [torch.zeros(1, 2)]

# シミュレーション実行
with torch.no_grad():
    for j in range(len(t_sim) - 1):
        h_current = buck_converter_cell(h_sim[-1], x_tensor[j : j + 1])
        h_sim.append(h_current)

h_sim_tensor = torch.cat(h_sim, dim=0)  # shape: (T+1, 2) みたいになる
iL_sim = h_sim_tensor[:, 0]
vC_sim = h_sim_tensor[:, 1]

# グラフ表示
fig, ax = plot_compare_tail(
    t_downsampled,
    iL_clipped,
    vC_clipped,
    "Measured",
    t_sim,
    iL_sim,
    vC_sim,
    "Predicted",
    T=params.T,
    title="Simulation Result",
)


if keep_log:
    save_figure_to_log(
        fig,
        "all_prediction",
        result_dir,
        "シミュレーション結果(0から1000周期までシミュレーションし、定常箇所と実機のデータの比較)",
    )

# %%
fig_list = plot_iLvC(
    t_sim,
    iL_sim,
    vC_sim,
    T=params.T,
    title="Simulation Result",
)

# %% [markdown]
# # GRU

# %% [markdown]
# ## 前処理
#
# 1. 教師データ: (実機データのノイズクリッピング前の波形) - (学習済み BuckConverterCell のおよそ定常部分)
# 2. 入力データ: iL, vC, vs, u, dt
# 3. データシーケンスの作成
# 4. train, valid, test に分割

# %%
def create_sequences(
    h_data: torch.Tensor,
    x_data: torch.Tensor,
    noise_data: torch.Tensor,
    seq_len: int,
) -> tuple[torch.Tensor, torch.Tensor]:
    """
    時系列データを作成
    入力: [iL, vC, vs, u, dt, iL_noise, vC_noise]
    出力: [iL_noise, vC_noise]
    """
    sequences = []
    targets = []

    for i in range(len(h_data) - seq_len):
        # 入力特徴量: [iL, vC, vs, u, dt] + 過去のノイズ [iL_noise, vC_noise]
        seq_input = []
        for j in range(seq_len):
            idx = i + j
            # 状態と入力
            features = torch.cat(
                [
                    h_data[idx],  # [iL, vC]
                    x_data[idx],  # [vs, u, dt]
                ]
            )
            # 過去のノイズ（存在する場合）
            if idx > 0:
                noise_features = noise_data[idx - 1]  # [iL_noise, vC_noise]
            else:
                noise_features = torch.zeros(2)
            # 結合: [iL, vC, vs, u, dt, iL_noise, vC_noise] = 7次元
            combined = torch.cat([features, noise_features])
            seq_input.append(combined)

        sequences.append(torch.stack(seq_input))
        targets.append(noise_data[i + seq_len])

    return torch.stack(sequences), torch.stack(targets)


# t_downsampled 部分を切り出す
h_sim_tensor = h_sim_tensor[1000 * params.samples_per_cycle + 1 :]
h_sim_tensor = h_sim_tensor[:-1]

iL_tensor = torch.tensor(iL_downsampled, dtype=torch.float32)
vC_tensor = torch.tensor(vC_downsampled, dtype=torch.float32)
h_meas_tensor = torch.stack([iL_tensor[:-1], vC_tensor[:-1]], dim=1)

n = min(h_meas_tensor.shape[0], h_sim_tensor.shape[0])
h_noise = h_meas_tensor[:n] - h_sim_tensor[:n]

# データセットを作成
iL_train = iL_tensor[: train_len + 1]
vC_train = vC_tensor[: train_len + 1]
h_train = torch.stack([iL_train[:-1], vC_train[:-1]], dim=1)
X_train_seq, y_train_seq = create_sequences(
    h_train,
    x_train,
    h_noise[: len(h_train)],
    params.seq_length,
)

iL_valid = iL_tensor[train_len : train_len + valid_len + 1]
vC_valid = vC_tensor[train_len : train_len + valid_len + 1]
h_valid = torch.stack([iL_valid[:-1], vC_valid[:-1]], dim=1)
X_valid_seq, y_valid_seq = create_sequences(
    h_valid,
    x_valid,
    h_noise[len(h_train) : len(h_train) + len(h_valid)],
    params.seq_length,
)

iL_test = iL_tensor[train_len + valid_len :]
vC_test = vC_tensor[train_len + valid_len :]
h_test = torch.stack([iL_test[:-1], vC_test[:-1]], dim=1)
X_test_seq, y_test_seq = create_sequences(
    h_test,
    x_test,
    h_noise[len(h_train) + len(h_valid) :],
    params.seq_length,
)

print(f"学習データ: {X_train_seq.shape} -> {y_train_seq.shape}")
print(f"検証データ: {X_valid_seq.shape} -> {y_valid_seq.shape}")
print(f"テストデータ: {X_test_seq.shape} -> {y_test_seq.shape}")
print(
    f"入力特徴量の次元: {X_train_seq.shape[2]} (iL, vC, vs, u, dt, iL_noise, vC_noise)"
)
# Out:
# 学習データ: torch.Size([590, 10, 7]) -> torch.Size([590, 2])
# 検証データ: torch.Size([590, 10, 7]) -> torch.Size([590, 2])
# テストデータ: torch.Size([790, 10, 7]) -> torch.Size([790, 2])
# 入力特徴量の次元: 7 (iL, vC, vs, u, dt, iL_noise, vC_noise)

# %%
# 学習データ
X_train_seq_np: np.ndarray = X_train_seq.detach().cpu().numpy()
y_train_seq_np: np.ndarray = y_train_seq.detach().cpu().numpy()

# 入力特徴量名と単位
feature_names: list[str] = ["iL", "vC", "vs", "u", "dt", "iL_noise", "vC_noise"]
feature_units: list[str] = ["[A]", "[V]", "[V]", "", "[s]", "[A]", "[V]"]


fig, axs = plt.subplots(7, 1, figsize=(14, 12), sharex=True)

last_timestep_features: np.ndarray = X_train_seq_np[:, -1, :]  # [N, 7]

# time_axisをt_train（μs単位）に
time_axis: np.ndarray = t_train[: X_train_seq_np.shape[0]] * 1e6  # μs

for i in range(7):
    axs[i].plot(time_axis, last_timestep_features[:, i], linewidth=1.5, alpha=0.7)
    axs[i].set_ylabel(f"{feature_names[i]} {feature_units[i]}", fontsize=11)
    axs[i].grid(True, alpha=0.3)
    axs[i].set_title(
        f"GRU Training Data: {feature_names[i]} (Value at Last Time Step)",
        fontsize=12,
        fontweight="bold",
    )

axs[6].set_xlabel("Time [μs]", fontsize=12)
plt.tight_layout()
plt.show()

if keep_log:
    save_figure_to_log(
        fig,
        "gru_training_data_features",
        result_dir,
        "GRU 学習データ",
    )

# %% [markdown]
# ## 学習

# %%
# 学習
gru_model = GRUModel(
    input_size=X_train_seq.shape[2],
    hidden_size=32,
    num_layers=2,
    output_size=2,
    seq_length=params.seq_length,
)


gru_optimizer = optim.Adam(gru_model.parameters(), lr=params.gru_lr)
gru_loss_fn = nn.MSELoss()

gru_loss_history = {"train": [], "valid": []}

for epoch in range(params.gru_epochs):
    # 学習モード
    gru_model.train()
    gru_optimizer.zero_grad()
    noise_pred_train = gru_model(X_train_seq)
    train_loss = gru_loss_fn(noise_pred_train, y_train_seq)
    train_loss.backward()
    gru_optimizer.step()

    gru_loss_history["train"].append(train_loss.item())

    # 検証モード
    gru_model.eval()
    with torch.no_grad():
        noise_pred_valid = gru_model(X_valid_seq)
        valid_loss = gru_loss_fn(noise_pred_valid, y_valid_seq)
        gru_loss_history["valid"].append(valid_loss.item())

    if (epoch + 1) % 50 == 0:
        print(
            f"Epoch {epoch + 1}/{params.gru_epochs}: "
            f"Train Loss={train_loss.item():.6e}, "
            f"Valid Loss={valid_loss.item():.6e}"
        )

gru_model.eval()
with torch.no_grad():
    noise_pred_test = gru_model(X_test_seq)
    test_loss = gru_loss_fn(noise_pred_test, y_test_seq)
    print(f"Test Loss={test_loss.item():.6e}")
# Out:
# Epoch 50/200: Train Loss=4.824617e-05, Valid Loss=5.048868e-05
# Epoch 100/200: Train Loss=3.188206e-05, Valid Loss=3.034804e-05
# Epoch 150/200: Train Loss=2.081511e-05, Valid Loss=1.982062e-05
# Epoch 200/200: Train Loss=1.423670e-05, Valid Loss=1.382944e-05
# Test Loss=1.681067e-05

# %% [markdown]
# ## 結果確認

# %%
# Lossの遷移をグラフ表示
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

epochs_list = range(1, params.gru_epochs + 1)
ax.plot(
    epochs_list, gru_loss_history["train"], label="Train Loss", linewidth=2, alpha=0.8
)
ax.plot(
    epochs_list, gru_loss_history["valid"], label="Valid Loss", linewidth=2, alpha=0.8
)

ax.set_xlabel("Epoch", fontsize=12)
ax.set_ylabel("Loss (MSE)", fontsize=12)
ax.set_title("Loss Transition", fontsize=14, fontweight="bold")
ax.set_yscale("log")
ax.grid(True, alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

# 画像をログに保存
if keep_log:
    save_figure_to_log(fig, "gru_loss_transition", result_dir, "GRU Lossの遷移")

# %%
# GRUでノイズを予測（テスト）
gru_model.eval()
with torch.no_grad():
    noise_pred_test = gru_model(X_test_seq)


noise_pred_test_cpu = noise_pred_test.detach().cpu()
noise_true_test_cpu = y_test_seq.detach().cpu()

# plot_compare_tail を使って比較（末尾N周期）
seq_len = int(params.seq_length)

t_noise = np.asarray(t_test[:-1])[seq_len:]
min_len = min(
    t_noise.shape[0],
    int(noise_true_test_cpu.shape[0]),
    int(noise_pred_test_cpu.shape[0]),
)

t_noise = t_noise[:min_len]
true_noise = noise_true_test_cpu[:min_len].numpy()
pred_noise = noise_pred_test_cpu[:min_len].numpy()

fig1, _ = plot_compare_tail(
    t1=t_noise,
    iL1=true_noise[:, 0],
    vC1=true_noise[:, 1],
    label1="true noise",
    t2=t_noise,
    iL2=pred_noise[:, 0],
    vC2=pred_noise[:, 1],
    label2="pred noise (GRU)",
    T=float(params.T),
    N_cycles=4,
    title="GRU noise prediction (test)",
)


if keep_log:
    save_figure_to_log(
        fig1,
        "gru_noise_pred_test_tail10T",
        result_dir,
        "GRU noise予測(テスト, tail10T)",
    )

# %% [markdown]
# # BuckConverterCell + GRU の結果

# %%
# プロット
N_cycles: int = 4
T: float = float(params.T)
seq_len: int = int(params.seq_length)

# --- BuckConverterCell: 実機時間(t_downsampled)に対応する末尾部分を抽出 ---
n_meas: int = int(len(t_downsampled))
t_sim_meas_raw: np.ndarray = np.asarray(t_sim[-n_meas:], dtype=float)

iL_sim_meas: np.ndarray = np.asarray(
    iL_sim[-n_meas:].detach().cpu().numpy(), dtype=float
)
vC_sim_meas: np.ndarray = np.asarray(
    vC_sim[-n_meas:].detach().cpu().numpy(), dtype=float
)

# t_sim末尾は (t_downsampled + offset) なので、offset を引いて合わせる
offset: float = float(t_sim_meas_raw[0] - float(t_downsampled[0]))
t_sim_meas: np.ndarray = t_sim_meas_raw - offset  # ≒ t_downsampled

# --- test区間をBuck側の時間で切り出す ---
t_test_np: np.ndarray = np.asarray(t_test, dtype=float)
start_idx: int = int(np.argmin(np.abs(t_sim_meas - float(t_test_np[0]))))
end_idx: int = min(start_idx + int(t_test_np.shape[0]), int(t_sim_meas.shape[0]))

t_test_used: np.ndarray = t_sim_meas[start_idx:end_idx]
iL_sim_test: np.ndarray = iL_sim_meas[start_idx:end_idx]
vC_sim_test: np.ndarray = vC_sim_meas[start_idx:end_idx]

# --- Measured(test) を同じ長さだけ取り出す ---
start_test_idx: int = int(train_len + valid_len)  # t_testと同じ開始位置

iL_meas_test: np.ndarray = np.asarray(
    iL_downsampled[start_test_idx : start_test_idx + int(t_test_used.shape[0])],
    dtype=float,
)
vC_meas_test: np.ndarray = np.asarray(
    vC_downsampled[start_test_idx : start_test_idx + int(t_test_used.shape[0])],
    dtype=float,
)

# --- GRU出力(pred_noise)は t_test[:-1][seq_len:] に対応 ---
t_noise_local: np.ndarray = np.asarray(t_test_used[:-1], dtype=float)[seq_len:]
pred_noise_np: np.ndarray = np.asarray(pred_noise, dtype=float)

min_len2: int = int(
    min(
        t_noise_local.shape[0],
        pred_noise_np.shape[0],
        iL_sim_test.shape[0] - 1 - seq_len,
        vC_sim_test.shape[0] - 1 - seq_len,
        iL_meas_test.shape[0] - 1 - seq_len,
        vC_meas_test.shape[0] - 1 - seq_len,
    )
)

if min_len2 <= 0:
    raise ValueError(
        "長さが合わず、描画できません。"
        " t_test/t_sim/pred_noise/seq_length の整合を確認してください。"
    )

# すべて同じ長さに揃える
# t は [s]
t_view: np.ndarray = t_noise_local[:min_len2]

iL_meas: np.ndarray = np.asarray(iL_meas_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]
vC_meas: np.ndarray = np.asarray(vC_meas_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]

iL_buck: np.ndarray = np.asarray(iL_sim_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]
vC_buck: np.ndarray = np.asarray(vC_sim_test[:-1], dtype=float)[
    seq_len : seq_len + min_len2
]

iL_gru: np.ndarray = pred_noise_np[:min_len2, 0]
vC_gru: np.ndarray = pred_noise_np[:min_len2, 1]

fig_iL, _, fig_vC, _ = plot_buck_gru_components_tail(
    t=t_view,
    iL_meas=iL_meas,
    vC_meas=vC_meas,
    iL_buck=iL_buck,
    vC_buck=vC_buck,
    iL_gru=iL_gru,
    vC_gru=vC_gru,
    T=T,
    N_cycles=float(N_cycles),
    title="note3 (test)",
    include_overlay=True,
)
plt.show()

if keep_log:
    save_figure_to_log(
        fig_iL,
        "tail4T_iL_meas_buck_gru_sum",
        result_dir,
        "iL: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )
    save_figure_to_log(
        fig_vC,
        "tail4T_vC_meas_buck_gru_sum",
        result_dir,
        "vC: Measured / Buck / GRU / Buck+GRU（末尾4周期）",
    )
